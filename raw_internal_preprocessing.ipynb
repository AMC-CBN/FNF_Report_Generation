# %%
def calculate_padding(image):
    # 이미지의 높이와 너비를 가져옵니다.
    height, width = image.shape[:2]

    if width > height:
        # 가로가 세로보다 긴 경우:
        # 세로 길이를 가로 길이와 동일하게 만들기 위해 세로에 패딩을 추가합니다.
        padding_size = width - height  # 추가해야 할 세로 패딩 크기를 계산합니다.
        top_pad = padding_size // 2  # 패딩의 절반을 위쪽에 추가합니다.
        bottom_pad = padding_size - top_pad  # 나머지 패딩을 아래쪽에 추가합니다.
        left_pad, right_pad = 0, 0  # 가로 방향으로는 패딩이 필요하지 않으므로 0으로 설정합니다.
    elif height > width:
        # 세로가 가로보다 긴 경우:
        # 가로 길이를 세로 길이와 동일하게 만들기 위해 가로에 패딩을 추가합니다.
        padding_size = height - width  # 추가해야 할 가로 패딩 크기를 계산합니다.
        left_pad = padding_size // 2  # 패딩의 절반을 왼쪽에 추가합니다.
        right_pad = padding_size - left_pad  # 나머지 패딩을 오른쪽에 추가합니다.
        top_pad, bottom_pad = 0, 0  # 세로 방향으로는 패딩이 필요하지 않으므로 0으로 설정합니다.
    else:
        # 가로와 세로 길이가 동일한 경우:
        # 이미 정사각형이므로 패딩이 필요하지 않습니다.
        top_pad, bottom_pad, left_pad, right_pad = 0, 0, 0, 0

    # 각 방향의 패딩 크기를 반환합니다. (왼쪽, 아래쪽, 오른쪽, 위쪽 순서)
    return (left_pad, bottom_pad, right_pad, top_pad)

# %%
def normalize_with_padding(image, desired_size):
    # 원하는 출력 크기의 너비와 높이를 가져옵니다.
    desired_width, desired_height = desired_size

    # 입력 이미지의 원본 크기 가져오기
    height, width = image.shape[:2]

    # 원본 이미지와 원하는 크기의 가로/세로 비율 계산
    aspect_ratio = width / height  # 원본 이미지의 가로세로 비율
    desired_aspect_ratio = desired_width / desired_height  # 원하는 출력 크기의 가로세로 비율

    # 가로세로 비율을 유지하면서 이미지 크기를 조정
    if aspect_ratio > desired_aspect_ratio:
        # 원본 이미지가 가로로 더 긴 경우
        new_width = desired_width  # 새로운 너비는 원하는 크기의 너비에 맞춤
        new_height = int(new_width / aspect_ratio)  # 비율을 유지하여 새로운 높이를 계산
    else:
        # 원본 이미지가 세로로 더 긴 경우
        new_height = desired_height  # 새로운 높이는 원하는 크기의 높이에 맞춤
        new_width = int(new_height * aspect_ratio)  # 비율을 유지하여 새로운 너비를 계산

    # 크기가 조정된 이미지를 생성
    resized_image = cv2.resize(image, (new_width, new_height))

    # 이미지를 정규화하여 픽셀 값을 [0, 1] 범위로 조정
    resized_image = resized_image - np.min(resized_image)  # 최소값을 0으로 맞춤
    resized_image = resized_image / np.max(resized_image)  # 최대값을 1로 맞춤

    # 필요한 경우 패딩을 추가하여 원하는 크기로 맞춤
    top_pad = (desired_height - new_height) // 2  # 위쪽 패딩 크기 계산
    bottom_pad = desired_height - new_height - top_pad  # 아래쪽 패딩 크기 계산
    left_pad = (desired_width - new_width) // 2  # 왼쪽 패딩 크기 계산
    right_pad = desired_width - new_width - left_pad  # 오른쪽 패딩 크기 계산

    # 패딩을 추가하여 최종적으로 정사각형 형태의 이미지를 생성
    padded_image = cv2.copyMakeBorder(
        resized_image,
        top_pad,
        bottom_pad,
        left_pad,
        right_pad,
        cv2.BORDER_CONSTANT  # 패딩 영역은 고정된 값으로 채움
    )

    # 리사이즈 비율 계산 (너비 비율, 높이 비율)
    resize_ratio = (new_width / width, new_height / height)

    # 패딩 추가 여부에 따라 유효한 리사이즈 비율 결정
    if top_pad == 0 and bottom_pad == 0:
        # 세로 방향으로 패딩이 추가되지 않은 경우
        effective_resize_ratio = resize_ratio[1]  # 세로 비율 반환
    else:
        # 가로 방향으로 패딩이 추가되지 않은 경우
        effective_resize_ratio = resize_ratio[0]  # 가로 비율 반환

    # 패딩이 추가된 이미지와 유효한 리사이즈 비율 반환
    return padded_image, effective_resize_ratio

# %%
def IP_OBD_a(serial, dicom_path):
    # DICOM 파일 읽기
    dcm_a = pydicom.dcmread(dicom_path)  # 지정된 경로에서 DICOM 파일을 읽어옵니다.
    dcm_a_p = dcm_a.pixel_array.astype(np.float32)  # DICOM 데이터를 float32 형식으로 변환합니다.

    # 이미지가 세로로 길쭉한 경우(높이가 너비보다 100 이상 큰 경우) 이미지 회전
    if dcm_a_p.shape[0] > dcm_a_p.shape[1] + 100:
        dcm_a_p = cv2.rotate(dcm_a_p, cv2.ROTATE_90_COUNTERCLOCKWISE)  # 반시계 방향으로 90도 회전

    # 특정 serial 번호에 대해 이미지 추가 회전 수행
    if serial in [
        7, 10, 97, 127, 133, 181, 213, 216, 233, 268, 342, 366, 431, 444, 484, 487, 495, 499, 533, 534,
        574, 624, 647, 662, 683, 688, 692, 700, 704, 720, 754, 774, 760, 761, 786, 795, 806, 869, 888,
        904, 913, 927, 945, 961, 983, 992, 997, 1003, 1039, 1112, 1122, 1124, 1134, 1149, 1151, 1174,
        1226, 1240, 1259, 1260, 1265, 1278, 1300, 1310, 1329, 1339, 1343, 1356, 1414, 1429, 1436, 1451,
        1515, 1581, 1594, 1631, 1650, 1682, 1715, 1724, 1768, 1790, 1827, 1833, 1894, 1909, 1923, 1927,
        1958, 2015, 2017, 2040, 2041, 2044, 2045
    ]:
        dcm_a_p = cv2.rotate(dcm_a_p, cv2.ROTATE_180)  # 이미지를 180도 회전
    elif serial in [51, 182, 243, 259, 443, 598, 628, 804, 1276, 1543, 1562, 2012]:
        dcm_a_p = cv2.rotate(dcm_a_p, cv2.ROTATE_90_CLOCKWISE)  # 이미지를 시계 방향으로 90도 회전

    # RescaleIntercept 속성이 존재하는 경우 LUT(Look-Up Table)를 적용
    if hasattr(dcm_a, 'RescaleIntercept'):
        if dcm_a.RescaleIntercept >= 0:  # RescaleIntercept 값이 0 이상인 경우
            dcm_a_p = apply_modality_lut(dcm_a_p, dcm_a)  # LUT 변환 수행

    # WindowCenter 및 WindowWidth 속성이 있는 경우, 윈도우 레벨 조정
    if hasattr(dcm_a, 'WindowCenter') and hasattr(dcm_a, 'WindowWidth'):
        window_center = dcm_a.WindowCenter  # 윈도우 센터 값
        window_width = dcm_a.WindowWidth  # 윈도우 폭 값
        dcm_a_p = np.clip(
            dcm_a_p,
            window_center - (window_width / 2),  # 최소값
            window_center + (window_width / 2)   # 최대값
        )

    # 원본 DICOM 이미지를 저장
    Dicom_image_AP = dcm_a_p

    # 패딩 추가 및 크기 정규화 (목표 크기: 800x800)
    dcm_a_p, dcm_a_p_ratio = normalize_with_padding(dcm_a_p, (800, 800))  # 정규화된 이미지와 리사이즈 비율 계산
    dcm_a_p_pad = calculate_padding(Dicom_image_AP)  # 패딩 크기 계산
    dcm_a_p = dcm_a_p.astype(np.float32)  # 이미지를 float32 형식으로 변환

    # 원본 이미지, 정규화된 이미지, 리사이즈 비율, 패딩 크기 반환
    return Dicom_image_AP, dcm_a_p, dcm_a_p_ratio, dcm_a_p_pad

# %%
def IP_OBD_t(serial, dicom_path):
    # DICOM 파일 읽기
    dcm_t = pydicom.dcmread(dicom_path)  # 지정된 경로에서 DICOM 파일을 읽어옵니다.
    dcm_t_p = dcm_t.pixel_array.astype(np.float32)  # DICOM 데이터를 float32 형식으로 변환

    # 이미지가 세로로 길쭉한 경우(높이가 너비보다 100 이상 큰 경우) 이미지 회전
    if dcm_t_p.shape[0] > dcm_t_p.shape[1] + 100:
        dcm_t_p = cv2.rotate(dcm_t_p, cv2.ROTATE_90_COUNTERCLOCKWISE)  # 반시계 방향으로 90도 회전

    # 특정 serial 번호에 따라 이미지 회전 수행
    if serial in [
        10, 13, 16, 24, 40, 43, 45, 51, 56, 59, 61, 70, 76, 77, 83, 96, 106, 108, 123, 126, 127, 144,
        149, 160, 162, 164, 167, 169, 173, 183, 187, 188, 191, 192, 231, 236, 239, 241, 245, 250, 252,
        254, 256, 263, 267, 270, 272, 277, 283, 297, 310, 314, 317, 323, 334, 342, 354, 364, 366, 367,
        374, 378, 386, 388, 389, 394, 403, 414, 416, 419, 424, 432, 438, 441, 442, 451, 452, 461, 466,
        467, 472, 473, 483, 485, 494, 495, 496, 505, 514, 525, 539, 547, 548, 553, 554, 559, 575, 587,
        600, 608, 614, 622, 624, 629, 630, 632, 634, 641, 643, 644, 652, 658, 662, 669, 673, 674, 685,
        692, 699, 701, 706, 714, 717, 720, 731, 738, 742, 744, 755, 766, 768, 772, 774, 775, 776, 781,
        786, 793, 805, 813, 816, 817, 820, 822, 825, 826, 847, 850, 855, 858, 862, 902, 903, 911, 912,
        917, 919, 920, 927, 934, 941, 942, 945, 949, 952, 963, 965, 968, 970, 983, 985, 992, 997, 1002,
        1003, 1006, 1017, 1018, 1021, 1027, 1036, 1037, 1039, 1048, 1051, 1060, 1068, 1083, 1087, 1104,
        1115, 1119, 1132, 1136, 1143, 1149, 1151, 1153, 1161, 1175, 1181, 1183, 1184, 1188, 1189, 1198,
        1199, 1209, 1211, 1213, 1226, 1231, 1237, 1238, 1240, 1243, 1247, 1258, 1260, 1261, 1269, 1274,
        1276, 1277, 1281, 1290, 1291, 1292, 1303, 1310, 1324, 1329, 1332, 1339, 1342, 1343, 1346, 1350,
        1352, 1359, 1362, 1366, 1367, 1370, 1376, 1386, 1387, 1395, 1398, 1403, 1404, 1408, 1411, 1423,
        1428, 1436, 1438, 1439, 1445, 1449, 1451, 1456, 1461, 1468, 1472, 1474, 1479, 1485, 1488, 1508,
        1511, 1515, 1526, 1542, 1544, 1551, 1555, 1558, 1566, 1577, 1581, 1582, 1590, 1594, 1602, 1604,
        1607, 1610, 1617, 1636, 1640, 1643, 1647, 1652, 1653, 1656, 1660, 1665, 1670, 1678, 1681, 1686,
        1688, 1690, 1693, 1694, 1707, 1711, 1717, 1720, 1721, 1728, 1733, 1752, 1753, 1763, 1764, 1771,
        1776, 1779, 1786, 1792, 1808, 1816, 1825, 1842, 1855, 1856, 1860, 1869, 1871, 1873, 1877, 1880,
        1891, 1893, 1894, 1901, 1905, 1913, 1917, 1929, 1931, 1932, 1943, 1950, 1956, 1958, 1970, 1993,
        2032, 2036, 2040, 2044, 2126, 2131, 374, 1516, 1517
    ]:
        dcm_t_p = cv2.rotate(dcm_t_p, cv2.ROTATE_180)  # 180도 회전
    elif serial in [585, 1334]:
        dcm_t_p = cv2.rotate(dcm_t_p, cv2.ROTATE_90_COUNTERCLOCKWISE)  # 반시계 방향으로 90도 회전
    elif serial in [120, 642, 780, 996, 2028, 2101, 2252]:
        dcm_t_p = cv2.rotate(dcm_t_p, cv2.ROTATE_90_CLOCKWISE)  # 시계 방향으로 90도 회전
    elif serial in [2269]:
        dcm_t_p = rotate(dcm_t_p, angle=-30, reshape=False)  # -30도 회전

    # RescaleIntercept 속성이 있는 경우 LUT(Look-Up Table) 적용
    if hasattr(dcm_t, 'RescaleIntercept'):
        if dcm_t.RescaleIntercept >= 0:  # RescaleIntercept 값이 0 이상이면
            dcm_t_p = apply_modality_lut(dcm_t_p, dcm_t)

    # WindowCenter 및 WindowWidth 속성이 있는 경우 윈도우 레벨 조정
    if hasattr(dcm_t, 'WindowCenter') and hasattr(dcm_t, 'WindowWidth'):
        window_center = dcm_t.WindowCenter  # 윈도우 센터 값
        window_width = dcm_t.WindowWidth  # 윈도우 폭 값
        dcm_t_p = np.clip(
            dcm_t_p,
            window_center - (window_width / 2),  # 최소값
            window_center + (window_width / 2)   # 최대값
        )

    # 원본 DICOM 이미지를 저장
    Dicom_image = dcm_t_p

    # 패딩을 추가하여 이미지 정규화 (크기: 800x800)
    dcm_t_p, dcm_t_p_ratio = normalize_with_padding(dcm_t_p, (800, 800))  # 정규화된 이미지와 리사이즈 비율 반환
    dcm_t_p_pad = calculate_padding(Dicom_image)  # 패딩 크기 계산
    dcm_t_p = dcm_t_p.astype(np.float32)  # float32 형식으로 변환

    # 원본 이미지, 정규화된 이미지, 리사이즈 비율, 패딩 크기 반환
    return Dicom_image, dcm_t_p, dcm_t_p_ratio, dcm_t_p_pad

# %%
import xml.etree.ElementTree as ET
import torch

def Crop_image_a(Dicom_image_AP, xml_path, classes):
    # XML 파일 파싱
    tree = ET.parse(xml_path)  # 주어진 XML 파일을 파싱하여 트리 구조 생성
    root = tree.getroot()  # XML의 루트 노드 가져오기
    
    cropped_image_Left = None  # 왼쪽 영역의 크롭된 이미지 초기화
    cropped_image_Right = None  # 오른쪽 영역의 크롭된 이미지 초기화
    
    for obj in root.findall('object'):  # XML에서 모든 'object' 태그를 찾음
        class_name = obj.find('name').text  # 클래스 이름 가져오기
        if class_name not in classes:  # 지정된 클래스 목록에 없는 경우 건너뛰기
            continue

        label = classes.index(class_name)  # 클래스 이름을 인덱스로 변환

        # 바운딩 박스 좌표 가져오기
        box = obj.find('bndbox')
        xmin = float(box.find('xmin').text)  # 박스의 왼쪽 x좌표
        ymin = float(box.find('ymin').text)  # 박스의 위쪽 y좌표
        xmax = float(box.find('xmax').text)  # 박스의 오른쪽 x좌표
        ymax = float(box.find('ymax').text)  # 박스의 아래쪽 y좌표
        
        if class_name == 'Left':  # 'Left' 클래스에 해당하는 경우
            xmin_crop = int(xmin)  # 크롭 영역의 왼쪽 x좌표
            ymin_crop = int(ymin)  # 크롭 영역의 위쪽 y좌표
            xmax_crop = int(xmax)  # 크롭 영역의 오른쪽 x좌표
            ymax_crop = int(ymax)  # 크롭 영역의 아래쪽 y좌표
            cropped_image_Left = Dicom_image_AP[ymin_crop:ymax_crop, xmin_crop:xmax_crop]  # 이미지 크롭
            cropped_image_Left = cv2.resize(cropped_image_Left, (256, 256))  # 크롭된 이미지를 256x256으로 리사이즈
            cropped_image_Left = cropped_image_Left - np.min(cropped_image_Left)  # 최소값을 0으로 정규화
            cropped_image_Left = cropped_image_Left / np.max(cropped_image_Left)  # 최대값을 1로 정규화
            cropped_image_Left = cropped_image_Left.astype(np.float32)  # float32 형식으로 변환
            
        if class_name == 'Right':  # 'Right' 클래스에 해당하는 경우
            xmin_crop = int(xmin)  # 크롭 영역의 왼쪽 x좌표
            ymin_crop = int(ymin)  # 크롭 영역의 위쪽 y좌표
            xmax_crop = int(xmax)  # 크롭 영역의 오른쪽 x좌표
            ymax_crop = int(ymax)  # 크롭 영역의 아래쪽 y좌표
            cropped_image_Right = Dicom_image_AP[ymin_crop:ymax_crop, xmin_crop:xmax_crop]  # 이미지 크롭
            cropped_image_Right = cv2.resize(cropped_image_Right, (256, 256))  # 크롭된 이미지를 256x256으로 리사이즈
            cropped_image_Right = cropped_image_Right - np.min(cropped_image_Right)  # 최소값을 0으로 정규화
            cropped_image_Right = cropped_image_Right / np.max(cropped_image_Right)  # 최대값을 1로 정규화
            cropped_image_Right = cropped_image_Right.astype(np.float32)  # float32 형식으로 변환
        
    # 크롭된 왼쪽 및 오른쪽 이미지를 반환
    return cropped_image_Left, cropped_image_Right

# %%
import xml.etree.ElementTree as ET
import torch

def Crop_image_t(Dicom_image_LAT, xml_path, classes):
    # XML 파일 파싱
    tree = ET.parse(xml_path)  # 주어진 XML 파일을 파싱하여 트리 구조 생성
    root = tree.getroot()  # XML의 루트 노드 가져오기

    classes = ['LAT_Neck']  # LAT_Neck 클래스만 처리
    LAT_cropped_image = None  # 크롭된 LAT 이미지 초기화

    for obj in root.findall('object'):  # XML에서 모든 'object' 태그를 찾음
        class_name = obj.find('name').text  # 클래스 이름 가져오기
        if class_name not in classes:  # 클래스 이름이 지정된 목록에 없는 경우 건너뛰기
            continue

        label = classes.index(class_name)  # 클래스 이름을 인덱스로 변환

        # 바운딩 박스 좌표 가져오기
        box = obj.find('bndbox')
        xmin = float(box.find('xmin').text)  # 박스의 왼쪽 x좌표
        ymin = float(box.find('ymin').text)  # 박스의 위쪽 y좌표
        xmax = float(box.find('xmax').text)  # 박스의 오른쪽 x좌표
        ymax = float(box.find('ymax').text)  # 박스의 아래쪽 y좌표

        # 크롭 영역 설정
        xmin_crop = int(xmin)  # 크롭된 이미지의 왼쪽 x좌표
        ymin_crop = int(ymin)  # 크롭된 이미지의 위쪽 y좌표
        xmax_crop = int(xmax)  # 크롭된 이미지의 오른쪽 x좌표
        ymax_crop = int(ymax)  # 크롭된 이미지의 아래쪽 y좌표

        # DICOM 이미지를 크롭
        LAT_cropped_image = Dicom_image_LAT[ymin_crop:ymax_crop, xmin_crop:xmax_crop]
        LAT_cropped_image = cv2.resize(LAT_cropped_image, (256, 256))  # 크롭된 이미지를 256x256으로 리사이즈
        LAT_cropped_image = LAT_cropped_image - np.min(LAT_cropped_image)  # 최소값을 0으로 정규화
        LAT_cropped_image = LAT_cropped_image / np.max(LAT_cropped_image)  # 최대값을 1로 정규화
        LAT_cropped_image = LAT_cropped_image.astype(np.float32)  # float32 형식으로 변환

    # 크롭된 LAT 이미지를 반환
    return LAT_cropped_image

# %%
# !pwd
import pandas as pd
import pydicom
import numpy as np
from sklearn.model_selection import train_test_split
import os
import pickle
from tqdm import tqdm
from pydicom.pixel_data_handlers.util import apply_modality_lut
from scipy.ndimage import rotate
import cv2

# Excel 파일 읽기 및 전처리
FNF_Excel = pd.read_excel('/workspace/FNF/labeling_detection_2to0.xlsx', usecols=[0, 7, 9, 11], engine='openpyxl', header=None)
FNF_Excel.columns = FNF_Excel.iloc[0]  # 첫 번째 행을 열 이름으로 설정
# 제외 기준에 따라 데이터 필터링
df_selected = FNF_Excel[['serial No.', 'exclusion', '정답label(by CT)']]
df_filtered = df_selected[df_selected['exclusion'] == 0]  # exclusion이 0인 데이터만 선택

# 통계 출력을 위한 초기 분석
print("\n=== 초기 데이터 분석 ===")
print("\nExclusion 값 분포:")
print(df_selected['exclusion'].value_counts())
print("\n선택된 데이터 (exclusion 0, 2):")
print("Exclusion 값별 개수:")
print(df_filtered['exclusion'].value_counts())
print("\nGarden Type 분포 (exclusion 0):")
print(df_filtered[df_filtered['exclusion'] == 0]['정답label(by CT)'].value_counts().sort_index())
print("\nGarden Type 분포 (exclusion 2):")
print(df_filtered[df_filtered['exclusion'] == 2]['정답label(by CT)'].value_counts().sort_index())

# 클래스 레이블 정의
classes_a = ['Left', 'Right']
classes_t = ['LAT_Neck']

# 데이터를 저장할 리스트 초기화
Serial_list, Garden_Type_list = [], []
Dicom_image_path_AP_list, Dicom_image_path_LAT_list = [], []
Detection_image_AP_list, Detection_image_LAT_list = [], []
Crop_AP_Right_image_list, Crop_AP_Left_image_list, Crop_LAT_image_list = [], [], []
Ratio_AP_list, Ratio_LAT_list = [], []
Pad_AP_list, Pad_LAT_list = [], []
Xml_path_AP_list, Xml_path_LAT_list = [], []

# tqdm으로 데이터 처리 진행 상황 표시
print("Processing data...")
for idx, row in tqdm(df_filtered.iterrows(), total=len(df_filtered), desc="Processing rows"):
    a_value = row['serial No.']  # serial No.
    p_value = row['정답label(by CT)']  # 정답 label

    # 파일 경로 생성
    folder_path = f'/workspace/FNF/nas/FNF/final_data/datasets/raw_internal/{a_value}'
    file_path_a = f'{folder_path}/{a_value}a000.dcm'
    file_path_t = f'{folder_path}/{a_value}t000.dcm'
    Xml_path_AP = f'/workspace/FNF/nas/FNF/final_data/Detect_Label/AP+Neck_label+100/{a_value}a.xml'
    Xml_path_LAT = f'/workspace/FNF/nas/FNF/final_data/Detect_Label/LAT_label+100/{a_value}t.xml'
    try:
        # AP 및 LAT 이미지 처리
        Dicom_image_AP, Detection_image_AP, AP_ratio, AP_pad = IP_OBD_a(a_value, file_path_a)
        Dicom_image_LAT, Detection_image_LAT, LAT_ratio, LAT_pad = IP_OBD_t(a_value, file_path_t)
        Crop_AP_Left_image, Crop_AP_Right_image = Crop_image_a(Dicom_image_AP, Xml_path_AP, classes_a)
        Crop_LAT_image = Crop_image_t(Dicom_image_LAT, Xml_path_LAT, classes_t)

        # 처리된 데이터를 리스트에 저장
        Serial_list.append(a_value)
        Dicom_image_path_AP_list.append(file_path_a)
        Dicom_image_path_LAT_list.append(file_path_t)
        Detection_image_AP_list.append(Detection_image_AP)
        Detection_image_LAT_list.append(Detection_image_LAT)
        Crop_AP_Right_image_list.append(Crop_AP_Right_image)
        Crop_AP_Left_image_list.append(Crop_AP_Left_image)
        Crop_LAT_image_list.append(Crop_LAT_image)
        Ratio_AP_list.append(AP_ratio)
        Ratio_LAT_list.append(LAT_ratio)
        Pad_AP_list.append(AP_pad)
        Pad_LAT_list.append(LAT_pad)
        Xml_path_AP_list.append(Xml_path_AP)
        Xml_path_LAT_list.append(Xml_path_LAT)
        Garden_Type_list.append(p_value - 1)  # Garden Type 값을 조정하여 저장

    except Exception as e:
        # 예외 발생 시 오류 메시지 출력 및 건너뛰기
        print(f"Error processing serial {a_value}: {e}")
        continue

# 클래스별 인덱스를 5개의 폴드로 나누기
print("Splitting data into folds...")
class_indices = {label: [i for i, l in enumerate(Garden_Type_list) if l == label] for label in range(4)}
folds = {f'fold{i+1}_indices': [] for i in range(5)}

for label, indices in class_indices.items():
    f1_indices, f2345_indices = train_test_split(indices, test_size=0.8, random_state=42)
    f2_indices, f345_indices = train_test_split(f2345_indices, test_size=0.75, random_state=42)
    f3_indices, f45_indices = train_test_split(f345_indices, test_size=0.66666, random_state=42)
    f4_indices, f5_indices = train_test_split(f45_indices, test_size=0.5, random_state=42)
    
    folds['fold1_indices'].extend(f1_indices)
    folds['fold2_indices'].extend(f2_indices)
    folds['fold3_indices'].extend(f3_indices)
    folds['fold4_indices'].extend(f4_indices)
    folds['fold5_indices'].extend(f5_indices)

# 프로세스별 데이터 딕셔너리 생성
processes = {
    'Paper': {
        'Serial': Serial_list,
        'Dicom_image_path_AP': Dicom_image_path_AP_list,
        'Dicom_image_path_LAT': Dicom_image_path_LAT_list,
        'Garden_Type': Garden_Type_list,
    },
    'AP_Detection': {
        'Serial': Serial_list,
        'Detection_image_AP': Detection_image_AP_list,
        'Ratio_AP_list': Ratio_AP_list,
        'Pad_AP_list': Pad_AP_list,
        'Xml_path_AP': Xml_path_AP_list,
    },
    'LAT_Detection': {
        'Serial': Serial_list,
        'Detection_image_LAT': Detection_image_LAT_list,
        'Ratio_LAT_list': Ratio_LAT_list,
        'Pad_LAT_list': Pad_LAT_list,
        'Xml_path_LAT': Xml_path_LAT_list,
    },
    'Classification': {
        'Serial': Serial_list,
        'Crop_AP_Right_image': Crop_AP_Right_image_list,
        'Crop_AP_Left_image': Crop_AP_Left_image_list,
        'Crop_LAT_image': Crop_LAT_image_list,
        'Garden_Type': Garden_Type_list,
    },
}

# 처리된 데이터를 각 프로세스별로 pickle 파일로 저장
pickle_save_dir = '/workspace/FNF/preprocessed_data/datasets/pickle_data_0218'
os.makedirs(pickle_save_dir, exist_ok=True)

print("Saving data...")
for process_name, process_data in tqdm(processes.items(), desc="Saving processes"):
    process_pickle_data = {f'fold{i+1}': {key: [process_data[key][j] for j in folds[f'fold{i+1}_indices']] 
                           for key in process_data.keys()} for i in range(5)}

    pickle_file_path = os.path.join(pickle_save_dir, f'FNF_{process_name}_data.pkl')
    with open(pickle_file_path, 'wb') as f:
        pickle.dump(process_pickle_data, f)
    
    print(f"{process_name} data saved to {pickle_file_path}")



def print_statistics(processes, folds):
    print("\n=== 데이터 통계 분석 ===")
    
    # 전체 데이터 통계
    total_samples = len(processes['Paper']['Serial'])
    print(f"\n전체 데이터 수: {total_samples}")
    
    garden_types = processes['Paper']['Garden_Type']
    unique_types = sorted(set(garden_types))
    
    # Exclusion 값별 통계
    excel_data = pd.read_excel('/workspace/FNF/labeling.xlsx')
    process_serials = set(processes['Paper']['Serial'])
    
    print("\n포함된 데이터의 Exclusion 분포:")
    for serial in process_serials:
        excel_row = excel_data[excel_data['serial No.'] == serial]
        if not excel_row.empty:
            exclusion_val = excel_row['exclusion'].iloc[0]
            garden_type = excel_row['정답label(by CT)'].iloc[0]
            print(f"Serial: {serial}, Exclusion: {exclusion_val}, Garden Type: {garden_type}")
    
    print("\n전체 Garden Type 분포:")
    for type_val in unique_types:
        count = garden_types.count(type_val)
        percentage = (count / total_samples) * 100
        print(f"Type {type_val + 1}: {count} ({percentage:.1f}%)")

    # Fold별 통계
    print("\nFold별 Garden Type 분포:")
    for fold_name, fold_indices in folds.items():
        fold_types = [garden_types[i] for i in fold_indices]
        print(f"\n{fold_name}:")
        print(f"총 데이터 수: {len(fold_indices)}")
        for type_val in unique_types:
            count = fold_types.count(type_val)
            percentage = (count / len(fold_indices)) * 100
            print(f"Type {type_val + 1}: {count} ({percentage:.1f}%)")

    # Serial number 범위
    serials = processes['Paper']['Serial']
    print(f"\nSerial Number 범위: {min(serials)} ~ {max(serials)}")
# 데이터 저장 전에 통계 출력
print_statistics(processes, folds)

# 처리된 데이터를 각 프로세스별로 pickle 파일로 저장
pickle_save_dir = '/workspace/FNF/preprocessed_data/datasets/pickle_data_1733'
os.makedirs(pickle_save_dir, exist_ok=True)

print("\nSaving data...")
for process_name, process_data in tqdm(processes.items(), desc="Saving processes"):
    process_pickle_data = {f'fold{i+1}': {key: [process_data[key][j] for j in folds[f'fold{i+1}_indices']] 
                           for key in process_data.keys()} for i in range(5)}

    pickle_file_path = os.path.join(pickle_save_dir, f'FNF_{process_name}_data.pkl')
    with open(pickle_file_path, 'wb') as f:
        pickle.dump(process_pickle_data, f)
    
    # 각 프로세스별 저장된 데이터 통계
    print(f"\n{process_name} 데이터 저장 완료:")
    print(f"파일 경로: {pickle_file_path}")
    print(f"Fold 수: {len(process_pickle_data)}")
    for fold_name, fold_data in process_pickle_data.items():
        print(f"{fold_name} 데이터 수: {len(fold_data['Serial'])}")
# Out:
# /workspace/FNF
#
# === 초기 데이터 분석 ===
#
# Exclusion 값 분포:
# 0            1589
# 1             779
# exclusion       1
# Name: exclusion, dtype: int64
#
# 선택된 데이터 (exclusion 0, 2):
# Exclusion 값별 개수:
# 0    1589
# Name: exclusion, dtype: int64
#
# Garden Type 분포 (exclusion 0):
# 1    379
# 2     69
# 3    476
# 4    664
# Name: 정답label(by CT), dtype: int64
#
# Garden Type 분포 (exclusion 2):
# Series([], Name: 정답label(by CT), dtype: int64)
# Processing data...
# Processing rows: 100%|█████████████████████████████████████████████████████████████████████████████████████████| 1589/1589 [1:36:37<00:00,  3.65s/it]
# Splitting data into folds...
# Saving data...
# Saving processes:   0%|                                                                                     | 0/4 [00:00<?, ?it/s]
# Paper data saved to /workspace/FNF/preprocessed_data/datasets/pickle_data_0218/FNF_Paper_data.pkl
# Saving processes:  50%|██████████████████████████████████████▌                                      | 2/4 [00:46<00:46, 23.05s/it]
# AP_Detection data saved to /workspace/FNF/preprocessed_data/datasets/pickle_data_0218/FNF_AP_Detection_data.pkl
# Saving processes:  75%|█████████████████████████████████████████████████████████▊                   | 3/4 [01:33<00:33, 33.23s/it]
# LAT_Detection data saved to /workspace/FNF/preprocessed_data/datasets/pickle_data_0218/FNF_LAT_Detection_data.pkl
# Saving processes: 100%|█████████████████████████████████████████████████████████████████████████████| 4/4 [01:50<00:00, 27.60s/it]
# Classification data saved to /workspace/FNF/preprocessed_data/datasets/pickle_data_0218/FNF_Classification_data.pkl
#
# === 데이터 통계 분석 ===
#
# 전체 데이터 수: 1589
# 포함된 데이터의 Exclusion 분포:
# Serial: 5, Exclusion: 0, Garden Type: 1
# Serial: 6, Exclusion: 0, Garden Type: 3
# Serial: 7, Exclusion: 0, Garden Type: 4
# Serial: 8, Exclusion: 0, Garden Type: 4
# Serial: 10, Exclusion: 0, Garden Type: 4
# Serial: 12, Exclusion: 0, Garden Type: 3
# Serial: 13, Exclusion: 0, Garden Type: 1
# Serial: 14, Exclusion: 0, Garden Type: 4
# Serial: 15, Exclusion: 0, Garden Type: 3
# Serial: 16, Exclusion: 0, Garden Type: 1
# Serial: 18, Exclusion: 0, Garden Type: 4
# Serial: 19, Exclusion: 0, Garden Type: 4
# Serial: 20, Exclusion: 0, Garden Type: 4
# Serial: 22, Exclusion: 0, Garden Type: 3
# Serial: 23, Exclusion: 0, Garden Type: 3
# Serial: 24, Exclusion: 0, Garden Type: 4
# Serial: 579, Exclusion: 2, Garden Type: 4
# Serial: 581, Exclusion: 2, Garden Type: 3
# Serial: 582, Exclusion: 2, Garden Type: 4
# Serial: 583, Exclusion: 2, Garden Type: 1
# Serial: 584, Exclusion: 2, Garden Type: 4
# Serial: 585, Exclusion: 2, Garden Type: 4
# Serial: 586, Exclusion: 2, Garden Type: 3
# Serial: 587, Exclusion: 2, Garden Type: 3
# Serial: 588, Exclusion: 2, Garden Type: 1?3?
# Serial: 589, Exclusion: 2, Garden Type: 3
# Serial: 590, Exclusion: 0, Garden Type: 4
# Serial: 591, Exclusion: 0, Garden Type: 3
# Serial: 592, Exclusion: 0, Garden Type: 4
# Serial: 593, Exclusion: 0, Garden Type: 3
# Serial: 597, Exclusion: 0, Garden Type: 1
# Serial: 598, Exclusion: 0, Garden Type: 3
# Serial: 599, Exclusion: 0, Garden Type: 3
# Serial: 600, Exclusion: 0, Garden Type: 4
# Serial: 601, Exclusion: 0, Garden Type: 1
# Serial: 602, Exclusion: 0, Garden Type: 1
# Serial: 606, Exclusion: 0, Garden Type: 4
# Serial: 607, Exclusion: 0, Garden Type: 3
# Serial: 608, Exclusion: 0, Garden Type: 3
# Serial: 611, Exclusion: 0, Garden Type: 1
# Serial: 612, Exclusion: 0, Garden Type: 1
# Serial: 613, Exclusion: 0, Garden Type: 2
# Serial: 614, Exclusion: 0, Garden Type: 3
# Serial: 615, Exclusion: 0, Garden Type: 1
# Serial: 616, Exclusion: 2, Garden Type: 3
# Serial: 620, Exclusion: 0, Garden Type: 3
# Serial: 621, Exclusion: 0, Garden Type: 4
# Serial: 622, Exclusion: 0, Garden Type: 4
# Serial: 624, Exclusion: 0, Garden Type: 4
# Serial: 627, Exclusion: 0, Garden Type: 4
# Serial: 628, Exclusion: 0, Garden Type: 1
# Serial: 629, Exclusion: 0, Garden Type: 4
# Serial: 630, Exclusion: 0, Garden Type: 1
# Serial: 631, Exclusion: 0, Garden Type: 4
# Serial: 632, Exclusion: 0, Garden Type: 1
# Serial: 634, Exclusion: 0, Garden Type: 1
# Serial: 635, Exclusion: 0, Garden Type: 4
# Serial: 637, Exclusion: 0, Garden Type: 4
# Serial: 639, Exclusion: 0, Garden Type: 4
# Serial: 640, Exclusion: 0, Garden Type: 4
# Serial: 641, Exclusion: 0, Garden Type: 4
# Serial: 642, Exclusion: 0, Garden Type: 1
# Serial: 643, Exclusion: 0, Garden Type: 3
# Serial: 644, Exclusion: 0, Garden Type: 4
# Serial: 645, Exclusion: 0, Garden Type: 4
# Serial: 647, Exclusion: 0, Garden Type: 4
# Serial: 648, Exclusion: 0, Garden Type: 1
# Serial: 652, Exclusion: 0, Garden Type: 3
# Serial: 653, Exclusion: 0, Garden Type: 4
# Serial: 654, Exclusion: 0, Garden Type: 1
# Serial: 655, Exclusion: 0, Garden Type: 2
# Serial: 656, Exclusion: 0, Garden Type: 4
# Serial: 658, Exclusion: 0, Garden Type: 3
# Serial: 662, Exclusion: 0, Garden Type: 1
# Serial: 663, Exclusion: 0, Garden Type: 1
# Serial: 666, Exclusion: 0, Garden Type: 4
# Serial: 667, Exclusion: 0, Garden Type: 4
# Serial: 668, Exclusion: 0, Garden Type: 3
# Serial: 669, Exclusion: 0, Garden Type: 3
# Serial: 673, Exclusion: 0, Garden Type: 3
# Serial: 674, Exclusion: 0, Garden Type: 4
# Serial: 675, Exclusion: 0, Garden Type: 3
# Serial: 676, Exclusion: 0, Garden Type: 1
# Serial: 677, Exclusion: 0, Garden Type: 4
# Serial: 678, Exclusion: 0, Garden Type: 2
# Serial: 679, Exclusion: 0, Garden Type: 3
# Serial: 683, Exclusion: 0, Garden Type: 4
# Serial: 684, Exclusion: 0, Garden Type: 4
# Serial: 685, Exclusion: 0, Garden Type: 3
# Serial: 686, Exclusion: 0, Garden Type: 2
# Serial: 688, Exclusion: 0, Garden Type: 4
# Serial: 689, Exclusion: 0, Garden Type: 4
# Serial: 691, Exclusion: 0, Garden Type: 1
# Serial: 692, Exclusion: 0, Garden Type: 4
# Serial: 693, Exclusion: 0, Garden Type: 2
# Serial: 694, Exclusion: 0, Garden Type: 4
# Serial: 695, Exclusion: 0, Garden Type: 1
# Serial: 696, Exclusion: 0, Garden Type: 2
# Serial: 697, Exclusion: 0, Garden Type: 4
# Serial: 699, Exclusion: 0, Garden Type: 3
# Serial: 700, Exclusion: 0, Garden Type: 1
# Serial: 701, Exclusion: 0, Garden Type: 1
# Serial: 703, Exclusion: 0, Garden Type: 4
# Serial: 704, Exclusion: 0, Garden Type: 4
# Serial: 706, Exclusion: 2, Garden Type: 3
# Serial: 707, Exclusion: 0, Garden Type: 1
# Serial: 708, Exclusion: 0, Garden Type: 4
# Serial: 711, Exclusion: 0, Garden Type: 4
# Serial: 714, Exclusion: 0, Garden Type: 1
# Serial: 715, Exclusion: 0, Garden Type: 2
# Serial: 716, Exclusion: 0, Garden Type: 1
# Serial: 717, Exclusion: 0, Garden Type: 1
# Serial: 718, Exclusion: 0, Garden Type: 3
# Serial: 720, Exclusion: 0, Garden Type: 4
# Serial: 722, Exclusion: 0, Garden Type: 3
# Serial: 723, Exclusion: 0, Garden Type: 1
# Serial: 725, Exclusion: 0, Garden Type: 4
# Serial: 726, Exclusion: 0, Garden Type: 1
# Serial: 727, Exclusion: 0, Garden Type: 1
# Serial: 729, Exclusion: 0, Garden Type: 1
# Serial: 730, Exclusion: 0, Garden Type: 4
# Serial: 731, Exclusion: 0, Garden Type: 4
# Serial: 732, Exclusion: 0, Garden Type: 2
# Serial: 733, Exclusion: 0, Garden Type: 4
# Serial: 735, Exclusion: 0, Garden Type: 3
# Serial: 738, Exclusion: 0, Garden Type: 4
# Serial: 739, Exclusion: 0, Garden Type: 2
# Serial: 740, Exclusion: 0, Garden Type: 4
# Serial: 742, Exclusion: 0, Garden Type: nan
# Serial: 743, Exclusion: 0, Garden Type: 4
# Serial: 744, Exclusion: 0, Garden Type: 2
# Serial: 745, Exclusion: 0, Garden Type: 4
# Serial: 747, Exclusion: 0, Garden Type: 4
# Serial: 749, Exclusion: 0, Garden Type: 4
# Serial: 750, Exclusion: 0, Garden Type: 3
# Serial: 751, Exclusion: 0, Garden Type: 1
# Serial: 752, Exclusion: 0, Garden Type: 1
# Serial: 754, Exclusion: 0, Garden Type: 4
# Serial: 755, Exclusion: 0, Garden Type: 3
# Serial: 756, Exclusion: 0, Garden Type: 2
# Serial: 757, Exclusion: 0, Garden Type: 4
# Serial: 758, Exclusion: 0, Garden Type: 4
# Serial: 759, Exclusion: 0, Garden Type: 4
# Serial: 760, Exclusion: 0, Garden Type: 4
# Serial: 761, Exclusion: 0, Garden Type: 4
# Serial: 762, Exclusion: 0, Garden Type: 4
# Serial: 766, Exclusion: 0, Garden Type: 4
# Serial: 767, Exclusion: 0, Garden Type: 1
# Serial: 768, Exclusion: 0, Garden Type: 4
# Serial: 771, Exclusion: 0, Garden Type: 2
# Serial: 772, Exclusion: 0, Garden Type: 1
# Serial: 773, Exclusion: 0, Garden Type: 4
# Serial: 774, Exclusion: 0, Garden Type: 3
# Serial: 775, Exclusion: 0, Garden Type: 1
# Serial: 776, Exclusion: 0, Garden Type: 1
# Serial: 778, Exclusion: 0, Garden Type: 4
# Serial: 779, Exclusion: 0, Garden Type: 1
# Serial: 780, Exclusion: 2, Garden Type: 1?
# Serial: 781, Exclusion: 0, Garden Type: 4
# Serial: 782, Exclusion: 0, Garden Type: 3
# Serial: 783, Exclusion: 2, Garden Type: 1?
# Serial: 784, Exclusion: 0, Garden Type: 4
# Serial: 785, Exclusion: 0, Garden Type: 1
# Serial: 786, Exclusion: 0, Garden Type: 4
# Serial: 789, Exclusion: 0, Garden Type: 4
# Serial: 792, Exclusion: 0, Garden Type: 3
# Serial: 793, Exclusion: 0, Garden Type: 3
# Serial: 795, Exclusion: 0, Garden Type: 4
# Serial: 796, Exclusion: 0, Garden Type: 4
# Serial: 797, Exclusion: 0, Garden Type: 4
# Serial: 799, Exclusion: 0, Garden Type: 1
# Serial: 800, Exclusion: 0, Garden Type: 3
# Serial: 801, Exclusion: 0, Garden Type: 4
# Serial: 804, Exclusion: 0, Garden Type: 4
# Serial: 805, Exclusion: 0, Garden Type: 2
# Serial: 806, Exclusion: 0, Garden Type: 4
# Serial: 807, Exclusion: 0, Garden Type: 1
# Serial: 808, Exclusion: 0, Garden Type: 2
# Serial: 810, Exclusion: 0, Garden Type: 2
# Serial: 811, Exclusion: 0, Garden Type: 1
# Serial: 813, Exclusion: 0, Garden Type: 1
# Serial: 814, Exclusion: 0, Garden Type: 4
# Serial: 815, Exclusion: 0, Garden Type: 1
# Serial: 816, Exclusion: 2, Garden Type: 1?4?
# Serial: 817, Exclusion: 0, Garden Type: 4
# Serial: 818, Exclusion: 0, Garden Type: 1
# Serial: 820, Exclusion: 0, Garden Type: 3
# Serial: 821, Exclusion: 0, Garden Type: 1
# Serial: 822, Exclusion: 0, Garden Type: 4
# Serial: 823, Exclusion: 0, Garden Type: 1
# Serial: 825, Exclusion: 0, Garden Type: 3
# Serial: 826, Exclusion: 2, Garden Type: 3?4?
# Serial: 827, Exclusion: 2, Garden Type: 3?4?
# Serial: 828, Exclusion: 0, Garden Type: 3?4?
# Serial: 831, Exclusion: 0, Garden Type: 3
# Serial: 832, Exclusion: 0, Garden Type: 1
# Serial: 833, Exclusion: 0, Garden Type: 1
# Serial: 834, Exclusion: 0, Garden Type: 4
# Serial: 835, Exclusion: 0, Garden Type: 3
# Serial: 839, Exclusion: 0, Garden Type: 3
# Serial: 842, Exclusion: 0, Garden Type: 2
# Serial: 843, Exclusion: 0, Garden Type: 4
# Serial: 844, Exclusion: 0, Garden Type: 1
# Serial: 845, Exclusion: 0, Garden Type: 4
# Serial: 846, Exclusion: 0, Garden Type: 1
# Serial: 847, Exclusion: 0, Garden Type: 2
# Serial: 850, Exclusion: 0, Garden Type: 3
# Serial: 851, Exclusion: 0, Garden Type: 3
# Serial: 852, Exclusion: 0, Garden Type: 3
# Serial: 853, Exclusion: 0, Garden Type: 3
# Serial: 854, Exclusion: 0, Garden Type: 4
# Serial: 855, Exclusion: 0, Garden Type: 1
# Serial: 856, Exclusion: 0, Garden Type: 3
# Serial: 858, Exclusion: 0, Garden Type: 4
# Serial: 859, Exclusion: 0, Garden Type: 1
# Serial: 860, Exclusion: 0, Garden Type: 4
# Serial: 862, Exclusion: 0, Garden Type: 4
# Serial: 863, Exclusion: 0, Garden Type: 1
# Serial: 865, Exclusion: 0, Garden Type: 4
# Serial: 866, Exclusion: 0, Garden Type: 4
# Serial: 868, Exclusion: 0, Garden Type: 4
# Serial: 869, Exclusion: 0, Garden Type: 1
# Serial: 870, Exclusion: 0, Garden Type: 4
# Serial: 872, Exclusion: 0, Garden Type: 1
# Serial: 876, Exclusion: 0, Garden Type: 1
# Serial: 877, Exclusion: 0, Garden Type: 4
# Serial: 878, Exclusion: 0, Garden Type: 4
# Serial: 880, Exclusion: 0, Garden Type: 3
# Serial: 881, Exclusion: 0, Garden Type: 4
# Serial: 883, Exclusion: 0, Garden Type: 3
# Serial: 885, Exclusion: 0, Garden Type: 3
# Serial: 888, Exclusion: 0, Garden Type: 3
# Serial: 889, Exclusion: 0, Garden Type: 4
# Serial: 891, Exclusion: 0, Garden Type: 3
# Serial: 892, Exclusion: 0, Garden Type: 4
# Serial: 895, Exclusion: 0, Garden Type: 3
# Serial: 896, Exclusion: 0, Garden Type: 3
# Serial: 898, Exclusion: 0, Garden Type: 3
# Serial: 899, Exclusion: 0, Garden Type: 4
# Serial: 901, Exclusion: 0, Garden Type: 3
# Serial: 902, Exclusion: 0, Garden Type: 4
# Serial: 903, Exclusion: 0, Garden Type: 4
# Serial: 904, Exclusion: 0, Garden Type: 1
# Serial: 906, Exclusion: 0, Garden Type: 1
# Serial: 908, Exclusion: 0, Garden Type: 3
# Serial: 911, Exclusion: 0, Garden Type: 4
# Serial: 912, Exclusion: 0, Garden Type: 1
# Serial: 913, Exclusion: 0, Garden Type: 1
# Serial: 916, Exclusion: 0, Garden Type: 3
# Serial: 917, Exclusion: 0, Garden Type: 4
# Serial: 919, Exclusion: 0, Garden Type: 3
# Serial: 920, Exclusion: 0, Garden Type: 3
# Serial: 921, Exclusion: 0, Garden Type: 3
# Serial: 922, Exclusion: 0, Garden Type: 3
# Serial: 1002, Exclusion: 0, Garden Type: 3
# Serial: 1003, Exclusion: 0, Garden Type: 1
# Serial: 1006, Exclusion: 0, Garden Type: 4
# Serial: 1007, Exclusion: 0, Garden Type: 1
# Serial: 1009, Exclusion: 0, Garden Type: 4
# Serial: 1010, Exclusion: 0, Garden Type: 1
# Serial: 1011, Exclusion: 0, Garden Type: 3
# Serial: 1012, Exclusion: 0, Garden Type: 4
# Serial: 1014, Exclusion: 0, Garden Type: 4
# Serial: 1016, Exclusion: 0, Garden Type: 3
# Serial: 1017, Exclusion: 0, Garden Type: 3
# Serial: 1018, Exclusion: 0, Garden Type: 4
# Serial: 1021, Exclusion: 0, Garden Type: 4
# Serial: 1022, Exclusion: 0, Garden Type: 4
# Serial: 1023, Exclusion: 0, Garden Type: 4
# Serial: 1025, Exclusion: 0, Garden Type: 4
# Serial: 1026, Exclusion: 0, Garden Type: 4
# Serial: 1027, Exclusion: 0, Garden Type: 4
# Serial: 1029, Exclusion: 0, Garden Type: 3
# Serial: 1031, Exclusion: 0, Garden Type: 3
# Serial: 1032, Exclusion: 0, Garden Type: 3
# Serial: 1033, Exclusion: 0, Garden Type: 4
# Serial: 1036, Exclusion: 0, Garden Type: 4
# Serial: 1037, Exclusion: 0, Garden Type: 1
# Serial: 1039, Exclusion: 0, Garden Type: 2
# Serial: 1040, Exclusion: 0, Garden Type: 4
# Serial: 1041, Exclusion: 0, Garden Type: 4
# Serial: 1044, Exclusion: 0, Garden Type: 3
# Serial: 1045, Exclusion: 0, Garden Type: 4
# Serial: 1048, Exclusion: 0, Garden Type: 3
# Serial: 1050, Exclusion: 0, Garden Type: 4
# Serial: 1051, Exclusion: 0, Garden Type: 4
# Serial: 1053, Exclusion: 0, Garden Type: 1
# Serial: 1054, Exclusion: 0, Garden Type: 4
# Serial: 1058, Exclusion: 0, Garden Type: 4
# Serial: 1060, Exclusion: 0, Garden Type: 4
# Serial: 1061, Exclusion: 0, Garden Type: 4
# Serial: 1062, Exclusion: 0, Garden Type: 4
# Serial: 1063, Exclusion: 0, Garden Type: 3
# Serial: 1065, Exclusion: 0, Garden Type: 3
# Serial: 1067, Exclusion: 0, Garden Type: 1
# Serial: 1068, Exclusion: 0, Garden Type: 3
# Serial: 1069, Exclusion: 0, Garden Type: 4
# Serial: 1070, Exclusion: 0, Garden Type: 1
# Serial: 1075, Exclusion: 0, Garden Type: 3
# Serial: 1077, Exclusion: 0, Garden Type: 1
# Serial: 1080, Exclusion: 0, Garden Type: 1
# Serial: 1081, Exclusion: 0, Garden Type: 4
# Serial: 1083, Exclusion: 0, Garden Type: 3
# Serial: 1087, Exclusion: 0, Garden Type: 4
# Serial: 1088, Exclusion: 0, Garden Type: 3
# Serial: 1090, Exclusion: 0, Garden Type: 4
# Serial: 1091, Exclusion: 0, Garden Type: 3
# Serial: 1092, Exclusion: 0, Garden Type: 4
# Serial: 1097, Exclusion: 0, Garden Type: 1
# Serial: 1098, Exclusion: 0, Garden Type: 4
# Serial: 1100, Exclusion: 0, Garden Type: 3
# Serial: 1102, Exclusion: 0, Garden Type: 1
# Serial: 1103, Exclusion: 0, Garden Type: 1
# Serial: 1104, Exclusion: 0, Garden Type: 4
# Serial: 1105, Exclusion: 0, Garden Type: 3
# Serial: 1110, Exclusion: 0, Garden Type: 4
# Serial: 1112, Exclusion: 0, Garden Type: 4
# Serial: 1115, Exclusion: 0, Garden Type: 1
# Serial: 1116, Exclusion: 0, Garden Type: 3
# Serial: 1118, Exclusion: 0, Garden Type: 2
# Serial: 1119, Exclusion: 0, Garden Type: 3
# Serial: 1120, Exclusion: 0, Garden Type: 3
# Serial: 1122, Exclusion: 0, Garden Type: 1
# Serial: 1124, Exclusion: 0, Garden Type: 3
# Serial: 1126, Exclusion: 0, Garden Type: 1
# Serial: 1127, Exclusion: 0, Garden Type: 4
# Serial: 1132, Exclusion: 0, Garden Type: 1
# Serial: 1133, Exclusion: 0, Garden Type: 1
# Serial: 1134, Exclusion: 0, Garden Type: 4
# Serial: 1135, Exclusion: 0, Garden Type: 4
# Serial: 1136, Exclusion: 0, Garden Type: 4
# Serial: 1139, Exclusion: 0, Garden Type: 1
# Serial: 1142, Exclusion: 0, Garden Type: 3
# Serial: 1143, Exclusion: 0, Garden Type: 2
# Serial: 1145, Exclusion: 0, Garden Type: 4
# Serial: 1146, Exclusion: 0, Garden Type: 1
# Serial: 1147, Exclusion: 0, Garden Type: 4
# Serial: 1149, Exclusion: 0, Garden Type: 1
# Serial: 1151, Exclusion: 0, Garden Type: 3
# Serial: 1152, Exclusion: 0, Garden Type: 4
# Serial: 1153, Exclusion: 0, Garden Type: 3
# Serial: 1155, Exclusion: 0, Garden Type: 4
# Serial: 1156, Exclusion: 0, Garden Type: 3
# Serial: 1157, Exclusion: 0, Garden Type: 4
# Serial: 1159, Exclusion: 0, Garden Type: 3
# Serial: 1161, Exclusion: 0, Garden Type: 3
# Serial: 1163, Exclusion: 0, Garden Type: 4
# Serial: 1165, Exclusion: 0, Garden Type: 3
# Serial: 1167, Exclusion: 0, Garden Type: 4
# Serial: 1170, Exclusion: 0, Garden Type: 3
# Serial: 1171, Exclusion: 0, Garden Type: 1
# Serial: 1172, Exclusion: 0, Garden Type: 4
# Serial: 1174, Exclusion: 0, Garden Type: 4
# Serial: 1175, Exclusion: 0, Garden Type: 4
# Serial: 1176, Exclusion: 0, Garden Type: 4
# Serial: 1177, Exclusion: 0, Garden Type: 1
# Serial: 1179, Exclusion: 0, Garden Type: 4
# Serial: 1181, Exclusion: 0, Garden Type: 4
# Serial: 1182, Exclusion: 0, Garden Type: 4
# Serial: 1183, Exclusion: 0, Garden Type: 4
# Serial: 1184, Exclusion: 0, Garden Type: 4
# Serial: 1186, Exclusion: 0, Garden Type: 1
# Serial: 1188, Exclusion: 0, Garden Type: 1
# Serial: 1189, Exclusion: 0, Garden Type: 1
# Serial: 1190, Exclusion: 0, Garden Type: 4
# Serial: 1191, Exclusion: 0, Garden Type: 4
# Serial: 1192, Exclusion: 0, Garden Type: 2
# Serial: 1193, Exclusion: 0, Garden Type: 3
# Serial: 1194, Exclusion: 0, Garden Type: 3
# Serial: 1195, Exclusion: 0, Garden Type: 1
# Serial: 1196, Exclusion: 0, Garden Type: 4
# Serial: 1198, Exclusion: 0, Garden Type: 1
# Serial: 1199, Exclusion: 0, Garden Type: 4
# Serial: 1200, Exclusion: 0, Garden Type: 4
# Serial: 1201, Exclusion: 0, Garden Type: 3
# Serial: 1202, Exclusion: 0, Garden Type: 2
# Serial: 1203, Exclusion: 0, Garden Type: 1
# Serial: 1204, Exclusion: 0, Garden Type: 4
# Serial: 1205, Exclusion: 0, Garden Type: 3
# Serial: 1206, Exclusion: 0, Garden Type: 4
# Serial: 1207, Exclusion: 0, Garden Type: 3
# Serial: 1209, Exclusion: 0, Garden Type: 1
# Serial: 1210, Exclusion: 0, Garden Type: 3
# Serial: 1211, Exclusion: 0, Garden Type: 3
# Serial: 1212, Exclusion: 0, Garden Type: 4
# Serial: 1213, Exclusion: 0, Garden Type: 3
# Serial: 1214, Exclusion: 0, Garden Type: 3
# Serial: 1215, Exclusion: 0, Garden Type: 1
# Serial: 1216, Exclusion: 0, Garden Type: 3
# Serial: 1217, Exclusion: 0, Garden Type: 1
# Serial: 1219, Exclusion: 0, Garden Type: 1
# Serial: 1224, Exclusion: 0, Garden Type: 4
# Serial: 1226, Exclusion: 0, Garden Type: 4
# Serial: 1229, Exclusion: 0, Garden Type: 2
# Serial: 1230, Exclusion: 0, Garden Type: 2
# Serial: 1231, Exclusion: 0, Garden Type: 3
# Serial: 1234, Exclusion: 0, Garden Type: 3
# Serial: 1235, Exclusion: 0, Garden Type: 3
# Serial: 1237, Exclusion: 0, Garden Type: 4
# Serial: 1238, Exclusion: 0, Garden Type: 4
# Serial: 1240, Exclusion: 0, Garden Type: 3
# Serial: 1241, Exclusion: 0, Garden Type: 3
# Serial: 1243, Exclusion: 0, Garden Type: 3
# Serial: 1245, Exclusion: 0, Garden Type: 3
# Serial: 1246, Exclusion: 0, Garden Type: 4
# Serial: 1247, Exclusion: 0, Garden Type: 3
# Serial: 1250, Exclusion: 0, Garden Type: 3
# Serial: 1251, Exclusion: 0, Garden Type: 4
# Serial: 1252, Exclusion: 0, Garden Type: 1
# Serial: 1256, Exclusion: 0, Garden Type: 1
# Serial: 1257, Exclusion: 0, Garden Type: 3
# Serial: 1258, Exclusion: 0, Garden Type: 1
# Serial: 1259, Exclusion: 0, Garden Type: 3
# Serial: 1260, Exclusion: 0, Garden Type: 3
# Serial: 1261, Exclusion: 0, Garden Type: 3
# Serial: 1262, Exclusion: 0, Garden Type: 2
# Serial: 1263, Exclusion: 0, Garden Type: 1
# Serial: 1264, Exclusion: 0, Garden Type: 4
# Serial: 1265, Exclusion: 0, Garden Type: 4
# Serial: 1267, Exclusion: 0, Garden Type: 3
# Serial: 1268, Exclusion: 0, Garden Type: 4
# Serial: 1269, Exclusion: 0, Garden Type: 4
# Serial: 1271, Exclusion: 0, Garden Type: 4
# Serial: 1274, Exclusion: 0, Garden Type: 3
# Serial: 1275, Exclusion: 0, Garden Type: 1
# Serial: 1276, Exclusion: 0, Garden Type: 1
# Serial: 1277, Exclusion: 0, Garden Type: 4
# Serial: 1278, Exclusion: 0, Garden Type: 4
# Serial: 1280, Exclusion: 0, Garden Type: 4
# Serial: 1281, Exclusion: 0, Garden Type: 3
# Serial: 1282, Exclusion: 0, Garden Type: 1
# Serial: 1283, Exclusion: 0, Garden Type: 4
# Serial: 1286, Exclusion: 0, Garden Type: 3
# Serial: 1287, Exclusion: 0, Garden Type: 3
# Serial: 1290, Exclusion: 0, Garden Type: 1
# Serial: 1291, Exclusion: 0, Garden Type: 4
# Serial: 1292, Exclusion: 0, Garden Type: 3
# Serial: 1293, Exclusion: 2, Garden Type: 4
# Serial: 1296, Exclusion: 0, Garden Type: 3
# Serial: 1298, Exclusion: 0, Garden Type: 3
# Serial: 1299, Exclusion: 0, Garden Type: 4
# Serial: 1300, Exclusion: 0, Garden Type: 4
# Serial: 1301, Exclusion: 0, Garden Type: 3
# Serial: 1303, Exclusion: 0, Garden Type: 3
# Serial: 1304, Exclusion: 0, Garden Type: 3
# Serial: 1305, Exclusion: 0, Garden Type: 4
# Serial: 1306, Exclusion: 0, Garden Type: 1
# Serial: 1308, Exclusion: 0, Garden Type: 1
# Serial: 1310, Exclusion: 0, Garden Type: 1
# Serial: 1311, Exclusion: 0, Garden Type: 1
# Serial: 1312, Exclusion: 0, Garden Type: 4
# Serial: 1314, Exclusion: 0, Garden Type: 3
# Serial: 1315, Exclusion: 0, Garden Type: 1
# Serial: 1316, Exclusion: 0, Garden Type: 3
# Serial: 1318, Exclusion: 0, Garden Type: 3
# Serial: 1324, Exclusion: 0, Garden Type: 1
# Serial: 1327, Exclusion: 0, Garden Type: 4
# Serial: 1328, Exclusion: 0, Garden Type: 1
# Serial: 1329, Exclusion: 0, Garden Type: 4
# Serial: 1331, Exclusion: 0, Garden Type: 3
# Serial: 1332, Exclusion: 0, Garden Type: 4
# Serial: 1333, Exclusion: 0, Garden Type: 1
# Serial: 1334, Exclusion: 0, Garden Type: 4
# Serial: 1335, Exclusion: 0, Garden Type: 3
# Serial: 1337, Exclusion: 0, Garden Type: 3
# Serial: 1339, Exclusion: 0, Garden Type: 4
# Serial: 1340, Exclusion: 0, Garden Type: 1
# Serial: 1342, Exclusion: 0, Garden Type: 4
# Serial: 1343, Exclusion: 0, Garden Type: 3
# Serial: 1344, Exclusion: 0, Garden Type: 4
# Serial: 1346, Exclusion: 0, Garden Type: 3
# Serial: 1348, Exclusion: 0, Garden Type: 4
# Serial: 1349, Exclusion: 0, Garden Type: 3
# Serial: 1350, Exclusion: 0, Garden Type: 3
# Serial: 1351, Exclusion: 0, Garden Type: 4
# Serial: 1352, Exclusion: 0, Garden Type: 4
# Serial: 1353, Exclusion: 0, Garden Type: 4
# Serial: 1354, Exclusion: 0, Garden Type: 4
# Serial: 1355, Exclusion: 0, Garden Type: 1
# Serial: 1356, Exclusion: 0, Garden Type: 4
# Serial: 1359, Exclusion: 0, Garden Type: 4
# Serial: 1362, Exclusion: 0, Garden Type: 4
# Serial: 1363, Exclusion: 0, Garden Type: 3
# Serial: 1365, Exclusion: 0, Garden Type: 3
# Serial: 1366, Exclusion: 0, Garden Type: 3
# Serial: 1367, Exclusion: 0, Garden Type: 4
# Serial: 1369, Exclusion: 0, Garden Type: 4
# Serial: 1370, Exclusion: 0, Garden Type: 3
# Serial: 1374, Exclusion: 0, Garden Type: 3
# Serial: 1375, Exclusion: 0, Garden Type: 1
# Serial: 1376, Exclusion: 0, Garden Type: 4
# Serial: 1377, Exclusion: 0, Garden Type: 3
# Serial: 1378, Exclusion: 0, Garden Type: 3
# Serial: 1380, Exclusion: 0, Garden Type: 3
# Serial: 1385, Exclusion: 0, Garden Type: 4
# Serial: 1386, Exclusion: 0, Garden Type: 1
# Serial: 1387, Exclusion: 0, Garden Type: 1
# Serial: 1390, Exclusion: 0, Garden Type: 4
# Serial: 1393, Exclusion: 0, Garden Type: 4
# Serial: 1394, Exclusion: 0, Garden Type: 1
# Serial: 1395, Exclusion: 0, Garden Type: 1
# Serial: 1398, Exclusion: 0, Garden Type: 4
# Serial: 1399, Exclusion: 0, Garden Type: 3
# Serial: 1402, Exclusion: 0, Garden Type: 1
# Serial: 1403, Exclusion: 0, Garden Type: 4
# Serial: 1404, Exclusion: 0, Garden Type: 3
# Serial: 1405, Exclusion: 0, Garden Type: 1
# Serial: 1406, Exclusion: 0, Garden Type: 3
# Serial: 1407, Exclusion: 0, Garden Type: 4
# Serial: 1408, Exclusion: 0, Garden Type: 3
# Serial: 1410, Exclusion: 0, Garden Type: 3
# Serial: 1411, Exclusion: 0, Garden Type: 3
# Serial: 1412, Exclusion: 0, Garden Type: 4
# Serial: 1413, Exclusion: 0, Garden Type: 4
# Serial: 1414, Exclusion: 0, Garden Type: 3
# Serial: 1415, Exclusion: 0, Garden Type: 3
# Serial: 1421, Exclusion: 0, Garden Type: 1
# Serial: 1423, Exclusion: 0, Garden Type: 3
# Serial: 1424, Exclusion: 0, Garden Type: 3
# Serial: 1426, Exclusion: 0, Garden Type: 4
# Serial: 1428, Exclusion: 0, Garden Type: 1
# Serial: 1429, Exclusion: 0, Garden Type: 4
# Serial: 1430, Exclusion: 0, Garden Type: 3
# Serial: 1431, Exclusion: 0, Garden Type: 1
# Serial: 1433, Exclusion: 0, Garden Type: 4
# Serial: 1435, Exclusion: 0, Garden Type: 3
# Serial: 1436, Exclusion: 0, Garden Type: 4
# Serial: 1438, Exclusion: 0, Garden Type: 4
# Serial: 1439, Exclusion: 0, Garden Type: 4
# Serial: 1440, Exclusion: 0, Garden Type: 4
# Serial: 1441, Exclusion: 0, Garden Type: 1
# Serial: 1442, Exclusion: 0, Garden Type: 1
# Serial: 1443, Exclusion: 0, Garden Type: 4
# Serial: 1445, Exclusion: 0, Garden Type: 4
# Serial: 1448, Exclusion: 0, Garden Type: 3
# Serial: 1449, Exclusion: 0, Garden Type: 4
# Serial: 1450, Exclusion: 0, Garden Type: 3
# Serial: 1451, Exclusion: 0, Garden Type: 3
# Serial: 1453, Exclusion: 0, Garden Type: 4
# Serial: 1454, Exclusion: 0, Garden Type: 4
# Serial: 1456, Exclusion: 0, Garden Type: 3
# Serial: 1458, Exclusion: 0, Garden Type: 4
# Serial: 1460, Exclusion: 0, Garden Type: 4
# Serial: 1461, Exclusion: 0, Garden Type: 1
# Serial: 1462, Exclusion: 0, Garden Type: 4
# Serial: 1463, Exclusion: 0, Garden Type: 1
# Serial: 1464, Exclusion: 0, Garden Type: 4
# Serial: 1465, Exclusion: 0, Garden Type: 3
# Serial: 1468, Exclusion: 0, Garden Type: 3
# Serial: 1470, Exclusion: 0, Garden Type: 4
# Serial: 1472, Exclusion: 0, Garden Type: 3
# Serial: 1473, Exclusion: 0, Garden Type: 4
# Serial: 1474, Exclusion: 0, Garden Type: 4
# Serial: 1475, Exclusion: 0, Garden Type: 3
# Serial: 1476, Exclusion: 0, Garden Type: 1
# Serial: 1477, Exclusion: 0, Garden Type: 1
# Serial: 1478, Exclusion: 0, Garden Type: 1
# Serial: 1479, Exclusion: 0, Garden Type: 1
# Serial: 1480, Exclusion: 0, Garden Type: 1
# Serial: 1482, Exclusion: 0, Garden Type: 1
# Serial: 1483, Exclusion: 0, Garden Type: 3
# Serial: 1485, Exclusion: 0, Garden Type: 3
# Serial: 1486, Exclusion: 0, Garden Type: 4
# Serial: 1487, Exclusion: 0, Garden Type: 1
# Serial: 1488, Exclusion: 0, Garden Type: 4
# Serial: 1489, Exclusion: 0, Garden Type: 1
# Serial: 1490, Exclusion: 0, Garden Type: 3
# Serial: 1492, Exclusion: 0, Garden Type: 3
# Serial: 1493, Exclusion: 0, Garden Type: 2
# Serial: 1496, Exclusion: 0, Garden Type: 3
# Serial: 1498, Exclusion: 0, Garden Type: 1
# Serial: 1500, Exclusion: 0, Garden Type: 4
# Serial: 1501, Exclusion: 0, Garden Type: 4
# Serial: 1502, Exclusion: 0, Garden Type: 4
# Serial: 1503, Exclusion: 0, Garden Type: 4
# Serial: 1504, Exclusion: 0, Garden Type: 4
# Serial: 1506, Exclusion: 0, Garden Type: 3
# Serial: 1508, Exclusion: 0, Garden Type: 3
# Serial: 1509, Exclusion: 0, Garden Type: 1
# Serial: 1510, Exclusion: 0, Garden Type: 3
# Serial: 1511, Exclusion: 0, Garden Type: 4
# Serial: 1513, Exclusion: 0, Garden Type: 1
# Serial: 1514, Exclusion: 0, Garden Type: 3
# Serial: 1515, Exclusion: 0, Garden Type: 3
# Serial: 1516, Exclusion: 0, Garden Type: 4
# Serial: 1517, Exclusion: 0, Garden Type: 4
# Serial: 1518, Exclusion: 0, Garden Type: 2
# Serial: 1520, Exclusion: 0, Garden Type: 1
# Serial: 1522, Exclusion: 0, Garden Type: 1
# Serial: 1523, Exclusion: 0, Garden Type: 3
# Serial: 1525, Exclusion: 0, Garden Type: 4
# Serial: 1526, Exclusion: 0, Garden Type: 3
# Serial: 1527, Exclusion: 0, Garden Type: 4
# Serial: 1528, Exclusion: 0, Garden Type: 4
# Serial: 1530, Exclusion: 0, Garden Type: 1
# Serial: 1531, Exclusion: 0, Garden Type: 4
# Serial: 1532, Exclusion: 0, Garden Type: 1
# Serial: 1533, Exclusion: 0, Garden Type: 3
# Serial: 1534, Exclusion: 0, Garden Type: 3
# Serial: 1535, Exclusion: 0, Garden Type: 3
# Serial: 1536, Exclusion: 0, Garden Type: 3
# Serial: 1537, Exclusion: 0, Garden Type: 4
# Serial: 1538, Exclusion: 0, Garden Type: 3
# Serial: 1541, Exclusion: 0, Garden Type: 4
# Serial: 1542, Exclusion: 0, Garden Type: 3
# Serial: 1543, Exclusion: 0, Garden Type: 4
# Serial: 1544, Exclusion: 0, Garden Type: 4
# Serial: 1545, Exclusion: 0, Garden Type: 3
# Serial: 1546, Exclusion: 0, Garden Type: 4
# Serial: 1549, Exclusion: 0, Garden Type: 3
# Serial: 1550, Exclusion: 0, Garden Type: 4
# Serial: 1551, Exclusion: 0, Garden Type: 3
# Serial: 1555, Exclusion: 0, Garden Type: 1
# Serial: 1556, Exclusion: 0, Garden Type: 4
# Serial: 1557, Exclusion: 0, Garden Type: 1
# Serial: 1558, Exclusion: 0, Garden Type: 3
# Serial: 1560, Exclusion: 0, Garden Type: 4
# Serial: 1561, Exclusion: 0, Garden Type: 1
# Serial: 1562, Exclusion: 0, Garden Type: 4
# Serial: 1564, Exclusion: 0, Garden Type: 4
# Serial: 1565, Exclusion: 0, Garden Type: 4
# Serial: 1566, Exclusion: 0, Garden Type: 4
# Serial: 1567, Exclusion: 0, Garden Type: 4
# Serial: 1569, Exclusion: 0, Garden Type: 4
# Serial: 1570, Exclusion: 0, Garden Type: 4
# Serial: 1575, Exclusion: 0, Garden Type: 3
# Serial: 1576, Exclusion: 0, Garden Type: 1
# Serial: 1577, Exclusion: 0, Garden Type: 4
# Serial: 1579, Exclusion: 0, Garden Type: 4
# Serial: 1580, Exclusion: 0, Garden Type: 4
# Serial: 1581, Exclusion: 0, Garden Type: 4
# Serial: 1582, Exclusion: 0, Garden Type: 1
# Serial: 1583, Exclusion: 0, Garden Type: 4
# Serial: 1584, Exclusion: 0, Garden Type: 3
# Serial: 1585, Exclusion: 0, Garden Type: 4
# Serial: 1586, Exclusion: 0, Garden Type: 3
# Serial: 1587, Exclusion: 0, Garden Type: 4
# Serial: 1588, Exclusion: 0, Garden Type: 3
# Serial: 1590, Exclusion: 0, Garden Type: 3
# Serial: 1591, Exclusion: 0, Garden Type: 4
# Serial: 1593, Exclusion: 0, Garden Type: 4
# Serial: 1594, Exclusion: 0, Garden Type: 4
# Serial: 1595, Exclusion: 0, Garden Type: 3
# Serial: 1597, Exclusion: 0, Garden Type: 4
# Serial: 1598, Exclusion: 0, Garden Type: 1
# Serial: 1601, Exclusion: 0, Garden Type: 2
# Serial: 1602, Exclusion: 0, Garden Type: 1
# Serial: 1603, Exclusion: 0, Garden Type: 4
# Serial: 1604, Exclusion: 0, Garden Type: 4
# Serial: 1605, Exclusion: 0, Garden Type: 4
# Serial: 1607, Exclusion: 0, Garden Type: 3
# Serial: 1608, Exclusion: 0, Garden Type: 4
# Serial: 1610, Exclusion: 0, Garden Type: 3
# Serial: 1611, Exclusion: 0, Garden Type: 3
# Serial: 1613, Exclusion: 0, Garden Type: 4
# Serial: 1614, Exclusion: 0, Garden Type: 4
# Serial: 1615, Exclusion: 0, Garden Type: 1
# Serial: 1616, Exclusion: 0, Garden Type: 3
# Serial: 1617, Exclusion: 0, Garden Type: 1
# Serial: 1618, Exclusion: 0, Garden Type: 3
# Serial: 1619, Exclusion: 0, Garden Type: 3
# Serial: 1621, Exclusion: 0, Garden Type: 1
# Serial: 1622, Exclusion: 0, Garden Type: 3
# Serial: 1625, Exclusion: 0, Garden Type: 3
# Serial: 1626, Exclusion: 0, Garden Type: 4
# Serial: 1627, Exclusion: 0, Garden Type: 3
# Serial: 1628, Exclusion: 0, Garden Type: 4
# Serial: 1630, Exclusion: 0, Garden Type: 3
# Serial: 1631, Exclusion: 0, Garden Type: 3
# Serial: 1633, Exclusion: 0, Garden Type: 3
# Serial: 1636, Exclusion: 0, Garden Type: 4
# Serial: 1637, Exclusion: 0, Garden Type: 4
# Serial: 1638, Exclusion: 0, Garden Type: 4
# Serial: 1640, Exclusion: 0, Garden Type: 3
# Serial: 1641, Exclusion: 0, Garden Type: 3
# ...
# Serial: 1906, Exclusion: 0, Garden Type: 1
# Serial: 1907, Exclusion: 0, Garden Type: 3
# Serial: 1908, Exclusion: 0, Garden Type: 4
# Serial: 1909, Exclusion: 0, Garden Type: 3
# Serial: 1910, Exclusion: 0, Garden Type: 1
# Serial: 1912, Exclusion: 0, Garden Type: 4
# Serial: 1913, Exclusion: 0, Garden Type: 4
# Serial: 1916, Exclusion: 0, Garden Type: 2
# Serial: 1917, Exclusion: 0, Garden Type: 3
# Serial: 1918, Exclusion: 0, Garden Type: 1
# Serial: 1919, Exclusion: 0, Garden Type: 4
# Serial: 1920, Exclusion: 0, Garden Type: 4
# Serial: 1921, Exclusion: 0, Garden Type: 3
# Serial: 1922, Exclusion: 0, Garden Type: 1
# Serial: 1923, Exclusion: 0, Garden Type: 3
# Serial: 1924, Exclusion: 0, Garden Type: 1
# Serial: 1925, Exclusion: 0, Garden Type: 4
# Serial: 1927, Exclusion: 0, Garden Type: 4
# Serial: 1928, Exclusion: 0, Garden Type: 1
# Serial: 1929, Exclusion: 0, Garden Type: 1
# Serial: 1930, Exclusion: 0, Garden Type: 3
# Serial: 1931, Exclusion: 0, Garden Type: 4
# Serial: 1932, Exclusion: 0, Garden Type: 4
# Serial: 1935, Exclusion: 0, Garden Type: 4
# Serial: 1936, Exclusion: 0, Garden Type: 4
# Serial: 1938, Exclusion: 0, Garden Type: 4
# Serial: 1939, Exclusion: 0, Garden Type: 1
# Serial: 1940, Exclusion: 0, Garden Type: 4
# Serial: 1941, Exclusion: 0, Garden Type: 1
# Serial: 1942, Exclusion: 0, Garden Type: 3
# Serial: 1943, Exclusion: 0, Garden Type: 1
# Serial: 1944, Exclusion: 0, Garden Type: 3
# Serial: 1947, Exclusion: 0, Garden Type: 3
# Serial: 1948, Exclusion: 0, Garden Type: 1
# Serial: 1950, Exclusion: 0, Garden Type: 1
# Serial: 1951, Exclusion: 0, Garden Type: 3
# Serial: 1952, Exclusion: 0, Garden Type: 1
# Serial: 1955, Exclusion: 0, Garden Type: 4
# Serial: 1956, Exclusion: 0, Garden Type: 3
# Serial: 1958, Exclusion: 0, Garden Type: 3
# Serial: 1959, Exclusion: 0, Garden Type: 4
# Serial: 1961, Exclusion: 0, Garden Type: 3
# Serial: 1962, Exclusion: 0, Garden Type: 3
# Serial: 1964, Exclusion: 0, Garden Type: 4
# Serial: 1968, Exclusion: 0, Garden Type: 1
# Serial: 1969, Exclusion: 0, Garden Type: 3
# Serial: 1970, Exclusion: 0, Garden Type: 4
# Serial: 1972, Exclusion: 0, Garden Type: 3
# Serial: 1977, Exclusion: 0, Garden Type: 3
# Serial: 1978, Exclusion: 0, Garden Type: 4
# Serial: 1979, Exclusion: 0, Garden Type: 4
# Serial: 1981, Exclusion: 0, Garden Type: 4
# Serial: 1983, Exclusion: 0, Garden Type: 3
# Serial: 1984, Exclusion: 0, Garden Type: 4
# Serial: 1986, Exclusion: 0, Garden Type: 3
# Serial: 1988, Exclusion: 0, Garden Type: 3
# Serial: 1990, Exclusion: 0, Garden Type: 1
# Serial: 1992, Exclusion: 0, Garden Type: 4
# Serial: 1993, Exclusion: 0, Garden Type: 4
# Serial: 1999, Exclusion: 0, Garden Type: 1
# Serial: 2000, Exclusion: 0, Garden Type: 4
# Serial: 2002, Exclusion: 0, Garden Type: 4
# Serial: 2003, Exclusion: 0, Garden Type: 3
# Serial: 2005, Exclusion: 0, Garden Type: 3
# Serial: 2007, Exclusion: 0, Garden Type: 3
# Serial: 2008, Exclusion: 0, Garden Type: 4
# Serial: 2010, Exclusion: 0, Garden Type: 4
# Serial: 2011, Exclusion: 0, Garden Type: 3
# Serial: 2012, Exclusion: 0, Garden Type: 4
# Serial: 2013, Exclusion: 0, Garden Type: 1
# Serial: 2014, Exclusion: 0, Garden Type: 3
# Serial: 2015, Exclusion: 0, Garden Type: 3
# Serial: 2016, Exclusion: 0, Garden Type: 3
# Serial: 2017, Exclusion: 0, Garden Type: 1
# Serial: 2018, Exclusion: 0, Garden Type: 1
# Serial: 2020, Exclusion: 0, Garden Type: 3
# Serial: 2021, Exclusion: 0, Garden Type: 1
# Serial: 2022, Exclusion: 0, Garden Type: 3
# Serial: 2023, Exclusion: 0, Garden Type: 3
# Serial: 2025, Exclusion: 0, Garden Type: 4
# Serial: 2026, Exclusion: 0, Garden Type: 4
# Serial: 2027, Exclusion: 0, Garden Type: 3
# Serial: 2028, Exclusion: 0, Garden Type: 1
# Serial: 2029, Exclusion: 0, Garden Type: 3
# Serial: 2032, Exclusion: 0, Garden Type: 1
# Serial: 2033, Exclusion: 0, Garden Type: 2
# Serial: 2034, Exclusion: 0, Garden Type: 4
# Serial: 2035, Exclusion: 0, Garden Type: 3
# Serial: 2036, Exclusion: 0, Garden Type: 3
# Serial: 2037, Exclusion: 0, Garden Type: 1
# Serial: 2038, Exclusion: 0, Garden Type: 4
# Serial: 2040, Exclusion: 0, Garden Type: 3
# Serial: 2041, Exclusion: 0, Garden Type: 1
# Serial: 2042, Exclusion: 0, Garden Type: 3
# Serial: 2043, Exclusion: 0, Garden Type: 4
# Serial: 2044, Exclusion: 0, Garden Type: 3
# Serial: 2045, Exclusion: 0, Garden Type: 4
# Serial: 2050, Exclusion: 0, Garden Type: 1
# Serial: 2051, Exclusion: 0, Garden Type: 1
# Serial: 2052, Exclusion: 0, Garden Type: 1
# Serial: 2053, Exclusion: 0, Garden Type: 4
# Serial: 2054, Exclusion: 0, Garden Type: 1
# Serial: 2056, Exclusion: 0, Garden Type: 4
# Serial: 2058, Exclusion: 0, Garden Type: 4
# Serial: 2059, Exclusion: 0, Garden Type: 4
# Serial: 2063, Exclusion: 0, Garden Type: 4
# Serial: 2064, Exclusion: 0, Garden Type: 3
# Serial: 2065, Exclusion: 0, Garden Type: 3
# Serial: 2066, Exclusion: 0, Garden Type: 4
# Serial: 2067, Exclusion: 0, Garden Type: 3
# Serial: 2068, Exclusion: 0, Garden Type: 1
# Serial: 2069, Exclusion: 0, Garden Type: 3
# Serial: 2070, Exclusion: 0, Garden Type: 3
# Serial: 2071, Exclusion: 0, Garden Type: 1
# Serial: 2072, Exclusion: 0, Garden Type: 1
# Serial: 2073, Exclusion: 0, Garden Type: 1
# Serial: 2074, Exclusion: 0, Garden Type: 2
# Serial: 2077, Exclusion: 0, Garden Type: 3
# Serial: 2078, Exclusion: 0, Garden Type: 1
# Serial: 2079, Exclusion: 0, Garden Type: 1
# Serial: 2080, Exclusion: 0, Garden Type: 4
# Serial: 2081, Exclusion: 0, Garden Type: 3
# Serial: 2082, Exclusion: 0, Garden Type: 1
# Serial: 2087, Exclusion: 0, Garden Type: 3
# Serial: 2088, Exclusion: 0, Garden Type: 1
# Serial: 2089, Exclusion: 0, Garden Type: 4
# Serial: 2090, Exclusion: 0, Garden Type: 1
# Serial: 2091, Exclusion: 0, Garden Type: 1
# Serial: 2092, Exclusion: 0, Garden Type: 3
# Serial: 2093, Exclusion: 0, Garden Type: 4
# Serial: 2094, Exclusion: 0, Garden Type: 1
# Serial: 2095, Exclusion: 0, Garden Type: 1
# Serial: 2098, Exclusion: 0, Garden Type: 4
# Serial: 2099, Exclusion: 0, Garden Type: 4
# Serial: 2101, Exclusion: 0, Garden Type: 4
# Serial: 2102, Exclusion: 0, Garden Type: 3
# Serial: 2103, Exclusion: 0, Garden Type: 1
# Serial: 2104, Exclusion: 0, Garden Type: 4
# Serial: 2105, Exclusion: 0, Garden Type: 3
# Serial: 2106, Exclusion: 0, Garden Type: 4
# Serial: 2108, Exclusion: 0, Garden Type: 3
# Serial: 2109, Exclusion: 0, Garden Type: 4
# Serial: 2111, Exclusion: 0, Garden Type: 3
# Serial: 2112, Exclusion: 0, Garden Type: 3
# Serial: 2113, Exclusion: 0, Garden Type: 3
# Serial: 2115, Exclusion: 0, Garden Type: 3
# Serial: 2117, Exclusion: 0, Garden Type: 3
# Serial: 2118, Exclusion: 0, Garden Type: 1
# Serial: 2119, Exclusion: 0, Garden Type: 3
# Serial: 2120, Exclusion: 0, Garden Type: 4
# Serial: 2121, Exclusion: 0, Garden Type: 3
# Serial: 2123, Exclusion: 0, Garden Type: 3
# Serial: 2125, Exclusion: 0, Garden Type: 4
# Serial: 2126, Exclusion: 0, Garden Type: 3
# Serial: 2127, Exclusion: 0, Garden Type: 1
# Serial: 2128, Exclusion: 0, Garden Type: 3
# Serial: 2129, Exclusion: 0, Garden Type: 1
# Serial: 2130, Exclusion: 0, Garden Type: 4
# Serial: 2131, Exclusion: 0, Garden Type: 1
# Serial: 2133, Exclusion: 0, Garden Type: 3
# Serial: 2134, Exclusion: 0, Garden Type: 3
# Serial: 2135, Exclusion: 0, Garden Type: 1
# Serial: 2136, Exclusion: 0, Garden Type: 3
# Serial: 2137, Exclusion: 0, Garden Type: 4
# Serial: 2138, Exclusion: 0, Garden Type: 4
# Serial: 2139, Exclusion: 0, Garden Type: 4
# Serial: 2141, Exclusion: 0, Garden Type: 4
# Serial: 2143, Exclusion: 0, Garden Type: 1
# Serial: 2144, Exclusion: 0, Garden Type: 1
# Serial: 2145, Exclusion: 0, Garden Type: 3
# Serial: 2147, Exclusion: 0, Garden Type: 1
# Serial: 2148, Exclusion: 0, Garden Type: 4
# Serial: 2150, Exclusion: 0, Garden Type: 4
# Serial: 2151, Exclusion: 0, Garden Type: 4
# Serial: 2152, Exclusion: 0, Garden Type: 4
# Serial: 2153, Exclusion: 0, Garden Type: 3
# Serial: 2154, Exclusion: 0, Garden Type: 3
# Serial: 2155, Exclusion: 0, Garden Type: 4
# Serial: 2159, Exclusion: 0, Garden Type: 4
# Serial: 2160, Exclusion: 0, Garden Type: 3
# Serial: 2161, Exclusion: 0, Garden Type: 1
# Serial: 2162, Exclusion: 0, Garden Type: 3
# Serial: 2163, Exclusion: 0, Garden Type: 3
# Serial: 2164, Exclusion: 0, Garden Type: 1
# Serial: 2165, Exclusion: 0, Garden Type: 4
# Serial: 2166, Exclusion: 0, Garden Type: 3
# Serial: 2167, Exclusion: 0, Garden Type: 1
# Serial: 2170, Exclusion: 0, Garden Type: 4
# Serial: 2171, Exclusion: 0, Garden Type: 2
# Serial: 2172, Exclusion: 0, Garden Type: 1
# Serial: 2173, Exclusion: 0, Garden Type: 4
# Serial: 2174, Exclusion: 0, Garden Type: 4
# Serial: 2176, Exclusion: 0, Garden Type: 1
# Serial: 2177, Exclusion: 0, Garden Type: 1
# Serial: 2179, Exclusion: 0, Garden Type: 4
# Serial: 2180, Exclusion: 0, Garden Type: 1
# Serial: 2181, Exclusion: 0, Garden Type: 4
# Serial: 2182, Exclusion: 0, Garden Type: 3
# Serial: 2185, Exclusion: 0, Garden Type: 3
# Serial: 2186, Exclusion: 0, Garden Type: 3
# Serial: 2187, Exclusion: 0, Garden Type: 3
# Serial: 2188, Exclusion: 0, Garden Type: 4
# Serial: 2189, Exclusion: 0, Garden Type: 1
# Serial: 2190, Exclusion: 0, Garden Type: 3
# Serial: 2192, Exclusion: 0, Garden Type: 4
# Serial: 2193, Exclusion: 0, Garden Type: 3
# Serial: 2195, Exclusion: 0, Garden Type: 3
# Serial: 2196, Exclusion: 0, Garden Type: 4
# Serial: 2198, Exclusion: 0, Garden Type: 3
# Serial: 2199, Exclusion: 0, Garden Type: 4
# Serial: 2201, Exclusion: 0, Garden Type: 4
# Serial: 2202, Exclusion: 0, Garden Type: 4
# Serial: 2204, Exclusion: 0, Garden Type: 1
# Serial: 2206, Exclusion: 0, Garden Type: 1
# Serial: 2209, Exclusion: 0, Garden Type: 1
# Serial: 2210, Exclusion: 0, Garden Type: 3
# Serial: 2211, Exclusion: 0, Garden Type: 1
# Serial: 2212, Exclusion: 0, Garden Type: 4
# Serial: 2213, Exclusion: 0, Garden Type: 3
# Serial: 2215, Exclusion: 0, Garden Type: 1
# Serial: 2218, Exclusion: 0, Garden Type: 4
# Serial: 2219, Exclusion: 0, Garden Type: 4
# Serial: 2220, Exclusion: 0, Garden Type: 4
# Serial: 2221, Exclusion: 0, Garden Type: 4
# Serial: 2223, Exclusion: 0, Garden Type: 4
# Serial: 2225, Exclusion: 0, Garden Type: 3
# Serial: 2227, Exclusion: 0, Garden Type: 1
# Serial: 2228, Exclusion: 0, Garden Type: 1
# Serial: 2231, Exclusion: 0, Garden Type: 3
# Serial: 2232, Exclusion: 0, Garden Type: 4
# Serial: 2233, Exclusion: 0, Garden Type: 4
# Serial: 2235, Exclusion: 0, Garden Type: 4
# Serial: 2238, Exclusion: 0, Garden Type: 4
# Serial: 2240, Exclusion: 0, Garden Type: 3
# Serial: 2241, Exclusion: 0, Garden Type: 4
# Serial: 2243, Exclusion: 0, Garden Type: 3
# Serial: 2244, Exclusion: 0, Garden Type: 2
# Serial: 2245, Exclusion: 0, Garden Type: 4
# Serial: 2247, Exclusion: 0, Garden Type: 4
# Serial: 2249, Exclusion: 0, Garden Type: 3
# Serial: 2250, Exclusion: 0, Garden Type: 4
# Serial: 2252, Exclusion: 0, Garden Type: 4
# Serial: 2253, Exclusion: 0, Garden Type: 3
# Serial: 2255, Exclusion: 0, Garden Type: 3
# Serial: 2256, Exclusion: 0, Garden Type: 3
# Serial: 2260, Exclusion: 0, Garden Type: 3
# Serial: 2261, Exclusion: 0, Garden Type: 1
# Serial: 2263, Exclusion: 0, Garden Type: 1
# Serial: 2264, Exclusion: 0, Garden Type: 1
# Serial: 2267, Exclusion: 0, Garden Type: 4
# Serial: 2269, Exclusion: 0, Garden Type: 1
# Serial: 2270, Exclusion: 0, Garden Type: 1
# Serial: 2271, Exclusion: 0, Garden Type: 3
# Serial: 2272, Exclusion: 0, Garden Type: 1
# Serial: 2273, Exclusion: 0, Garden Type: 1
# Serial: 2275, Exclusion: 0, Garden Type: 3
# Serial: 2276, Exclusion: 0, Garden Type: 2
# Serial: 2279, Exclusion: 0, Garden Type: 4
# Serial: 2280, Exclusion: 0, Garden Type: 4
# Serial: 2281, Exclusion: 0, Garden Type: 3
# Serial: 2283, Exclusion: 0, Garden Type: 4
# Serial: 2284, Exclusion: 0, Garden Type: 3
# Serial: 2285, Exclusion: 0, Garden Type: 1
# Serial: 2286, Exclusion: 0, Garden Type: 4
# Serial: 2288, Exclusion: 0, Garden Type: 4
# Serial: 2289, Exclusion: 0, Garden Type: 2
# Serial: 2290, Exclusion: 0, Garden Type: 4
# Serial: 2291, Exclusion: 0, Garden Type: 3
# Serial: 2292, Exclusion: 0, Garden Type: 1
# Serial: 2293, Exclusion: 0, Garden Type: 3
# Serial: 2294, Exclusion: 0, Garden Type: 3
# Serial: 2295, Exclusion: 0, Garden Type: 3
# Serial: 2297, Exclusion: 0, Garden Type: 4
# Serial: 2298, Exclusion: 0, Garden Type: 4
# Serial: 2300, Exclusion: 0, Garden Type: 3
# Serial: 2301, Exclusion: 0, Garden Type: 3
# Serial: 2303, Exclusion: 0, Garden Type: 3
# Serial: 2304, Exclusion: 0, Garden Type: 3
# Serial: 2305, Exclusion: 0, Garden Type: 1
# Serial: 2306, Exclusion: 0, Garden Type: 4
# Serial: 2308, Exclusion: 0, Garden Type: 3
# Serial: 2309, Exclusion: 0, Garden Type: 4
# Serial: 2310, Exclusion: 0, Garden Type: 4
# Serial: 2311, Exclusion: 0, Garden Type: 3
# Serial: 2313, Exclusion: 0, Garden Type: 4
# Serial: 2314, Exclusion: 0, Garden Type: 3
# Serial: 2315, Exclusion: 0, Garden Type: 4
# Serial: 2317, Exclusion: 0, Garden Type: 1
# Serial: 2318, Exclusion: 0, Garden Type: 4
# Serial: 2319, Exclusion: 0, Garden Type: 4
# Serial: 2320, Exclusion: 0, Garden Type: 3
# Serial: 2321, Exclusion: 0, Garden Type: 4
# Serial: 2324, Exclusion: 0, Garden Type: 3
# Serial: 2325, Exclusion: 0, Garden Type: 3
# Serial: 2327, Exclusion: 0, Garden Type: 1
# Serial: 2328, Exclusion: 0, Garden Type: 3
# Serial: 2331, Exclusion: 0, Garden Type: 3
# Serial: 2332, Exclusion: 0, Garden Type: 3
# Serial: 2334, Exclusion: 0, Garden Type: 1
# Serial: 2335, Exclusion: 0, Garden Type: 3
# Serial: 2336, Exclusion: 0, Garden Type: 4
# Serial: 2337, Exclusion: 0, Garden Type: 3
# Serial: 2339, Exclusion: 0, Garden Type: 3
# Serial: 2340, Exclusion: 0, Garden Type: 1
# Serial: 2341, Exclusion: 0, Garden Type: 3
# Serial: 2342, Exclusion: 0, Garden Type: 3
# Serial: 2344, Exclusion: 0, Garden Type: 1
# Serial: 2348, Exclusion: 0, Garden Type: 4
# Serial: 2351, Exclusion: 0, Garden Type: 3
# Serial: 2352, Exclusion: 0, Garden Type: 3
# Serial: 2354, Exclusion: 0, Garden Type: 3
# Serial: 2355, Exclusion: 0, Garden Type: 3
# Serial: 2357, Exclusion: 0, Garden Type: 1
# Serial: 2359, Exclusion: 0, Garden Type: 1
# Serial: 2360, Exclusion: 0, Garden Type: 4
# Serial: 2362, Exclusion: 0, Garden Type: 3
# Serial: 2363, Exclusion: 0, Garden Type: 1
# Serial: 2364, Exclusion: 0, Garden Type: 1
# Serial: 2366, Exclusion: 0, Garden Type: 4
# Serial: 2367, Exclusion: 0, Garden Type: 1
# Serial: 2368, Exclusion: 0, Garden Type: 3
#
# 전체 Garden Type 분포:
# Type 1: 379 (23.9%)
# Type 2: 69 (4.3%)
# Type 3: 476 (30.0%)
# Type 4: 664 (41.8%)
# Type nan: 1 (0.1%)
#
# Fold별 Garden Type 분포:
#
# fold1_indices:
# 총 데이터 수: 315
# Type 1: 75 (23.8%)
# Type 2: 13 (4.1%)
# Type 3: 95 (30.2%)
# Type 4: 132 (41.9%)
# Type nan: 0 (0.0%)
#
# fold2_indices:
# 총 데이터 수: 318
# Type 1: 76 (23.9%)
# Type 2: 14 (4.4%)
# Type 3: 95 (29.9%)
# Type 4: 133 (41.8%)
# Type nan: 0 (0.0%)
#
# fold3_indices:
# 총 데이터 수: 318
# Type 1: 76 (23.9%)
# Type 2: 14 (4.4%)
# Type 3: 95 (29.9%)
# Type 4: 133 (41.8%)
# Type nan: 0 (0.0%)
#
# fold4_indices:
# 총 데이터 수: 318
# Type 1: 76 (23.9%)
# Type 2: 14 (4.4%)
# Type 3: 95 (29.9%)
# Type 4: 133 (41.8%)
# Type nan: 0 (0.0%)
#
# fold5_indices:
# 총 데이터 수: 319
# Type 1: 76 (23.8%)
# Type 2: 14 (4.4%)
# Type 3: 96 (30.1%)
# Type 4: 133 (41.7%)
# Type nan: 0 (0.0%)
#
# Serial Number 범위: 5 ~ 2368
#
# Saving data...
# Saving processes:   0%|                                                                                     | 0/4 [00:00<?, ?it/s]
# Paper 데이터 저장 완료:
# 파일 경로: /workspace/FNF/preprocessed_data/datasets/pickle_data_1733/FNF_Paper_data.pkl
# Fold 수: 5
# fold1 데이터 수: 315
# fold2 데이터 수: 318
# fold3 데이터 수: 318
# fold4 데이터 수: 318
# fold5 데이터 수: 319
# Saving processes:  50%|██████████████████████████████████████▌                                      | 2/4 [00:33<00:33, 16.81s/it]
# AP_Detection 데이터 저장 완료:
# 파일 경로: /workspace/FNF/preprocessed_data/datasets/pickle_data_1733/FNF_AP_Detection_data.pkl
# Fold 수: 5
# fold1 데이터 수: 315
# fold2 데이터 수: 318
# fold3 데이터 수: 318
# fold4 데이터 수: 318
# fold5 데이터 수: 319
# Saving processes:  75%|█████████████████████████████████████████████████████████▊                   | 3/4 [01:09<00:24, 24.74s/it]
# LAT_Detection 데이터 저장 완료:
# 파일 경로: /workspace/FNF/preprocessed_data/datasets/pickle_data_1733/FNF_LAT_Detection_data.pkl
# Fold 수: 5
# fold1 데이터 수: 315
# fold2 데이터 수: 318
# fold3 데이터 수: 318
# fold4 데이터 수: 318
# fold5 데이터 수: 319
# Saving processes: 100%|█████████████████████████████████████████████████████████████████████████████| 4/4 [01:22<00:00, 20.58s/it]
# Classification 데이터 저장 완료:
# 파일 경로: /workspace/FNF/preprocessed_data/datasets/pickle_data_1733/FNF_Classification_data.pkl
# Fold 수: 5
# fold1 데이터 수: 315
# fold2 데이터 수: 318
# fold3 데이터 수: 318
# fold4 데이터 수: 318
# fold5 데이터 수: 319

# %%
import pandas as pd
import numpy as np

# Excel 파일 읽기
FNF_Excel = pd.read_excel('/workspace/FNF/labeling.xlsx', usecols=[0, 7, 9], engine='openpyxl', header=None)
FNF_Excel.columns = FNF_Excel.iloc[0]
FNF_Excel = FNF_Excel.iloc[1:]

# exclusion=2인 데이터 확인
exclusion2_data = FNF_Excel[FNF_Excel['exclusion'] == 2]
exclusion0_data = FNF_Excel[FNF_Excel['exclusion'] == 0]


# 1.0 제외 대상
exclude_1_0 = [51, 259, 598, 554, 1334]

# Internal Raw Dicom 제외 대상
exclude_internal = [98, 141, 161, 228, 501, 748, 1592, 1769]

# LAT Detection box 추가 데이터
add_lat = [808, 1175, 1363, 1587]

# Exclusion=0에서 각 데이터 존재 여부 확인
print("1.0 제외 대상 중 Exclusion=0에 있는 데이터:")
check_1_0 = FNF_Excel[
    (FNF_Excel['exclusion'] == 0) & 
    (FNF_Excel['serial No.'].isin(exclude_1_0))
]
print(check_1_0[['serial No.', 'exclusion', '정답label(by CT)']])

print("\nInternal Raw Dicom 제외 대상 중 Exclusion=0에 있는 데이터:")
check_internal = FNF_Excel[
    (FNF_Excel['exclusion'] == 0) & 
    (FNF_Excel['serial No.'].isin(exclude_internal))
]
print(check_internal[['serial No.', 'exclusion', '정답label(by CT)']])

print("\nLAT Detection box 추가 데이터 중 Exclusion=0에 있는 데이터:")
check_lat = FNF_Excel[
    (FNF_Excel['exclusion'] == 0) & 
    (FNF_Excel['serial No.'].isin(add_lat))
]
print(check_lat[['serial No.', 'exclusion', '정답label(by CT)']])
# 레이블 종류별로 분류
def classify_label(label):
    if pd.isna(label):
        return 'NaN'
    elif isinstance(label, (int, float)):
        return f'Type {int(label)}'
    elif '?' in str(label):
        return str(label)
    return str(label)

# 결과 출력
print("Exclusion=2 데이터 (31개):")
print(exclusion2_data[['serial No.', 'exclusion', '정답label(by CT)']].sort_values('serial No.'))

print("\n레이블 종류별 개수:")
label_counts = exclusion2_data['정답label(by CT)'].apply(classify_label).value_counts()
print(label_counts)

# 결과 출력
print("Exclusion=0 데이터 (1558개):")
print(exclusion0_data[['serial No.', 'exclusion', '정답label(by CT)']].sort_values('serial No.'))

print("\nExclusion=0 데이터 레이블 종류별 개수:")
label_counts = exclusion0_data['정답label(by CT)'].apply(classify_label).value_counts()
print(label_counts)


exclude_serials = [51, 259, 598, 554, 1334]  # 1.0에서 제외되어야 할 데이터
add_serials = [808, 1175, 1363, 1587]  # 1.1 & 2.0에서 추가된 데이터

# exclusion=0 데이터 중 제외 대상 확인
exclusion0_exclude = FNF_Excel[
    (FNF_Excel['exclusion'] == 0) & 
    (FNF_Excel['serial No.'].isin(exclude_serials))
]
print("Exclusion=0에서 제외되어야 할 데이터:")
print(exclusion0_exclude[['serial No.', 'exclusion', '정답label(by CT)']])

# exclusion=0 데이터 중 추가된 데이터 확인
exclusion0_add = FNF_Excel[
    (FNF_Excel['exclusion'] == 0) & 
    (FNF_Excel['serial No.'].isin(add_serials))
]
print("\nExclusion=0에 이미 포함된 추가 데이터:")
print(exclusion0_add[['serial No.', 'exclusion', '정답label(by CT)']])

# 제외/추가 데이터의 Type 확인
exclude_serials = [51, 259, 598, 554, 1334]
add_serials = [808, 1175, 1363, 1587]

print("제외 데이터의 Type:")
exclude_data = FNF_Excel[FNF_Excel['serial No.'].isin(exclude_serials)]
print(exclude_data[['serial No.', 'exclusion', '정답label(by CT)']])

print("\n추가 데이터의 Type:")
add_data = FNF_Excel[FNF_Excel['serial No.'].isin(add_serials)]
print(add_data[['serial No.', 'exclusion', '정답label(by CT)']])
